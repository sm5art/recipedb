# %%
import pandas as pd

DATA_HOME = 'data/'

# %%
def read_csv(fil):
    return pd.read_csv(DATA_HOME + fil)

# %%
category_csv = read_csv('food_category.csv')
category_csv
# Out:
#     id  code                          description
# 0    1   100               Dairy and Egg Products
# 1    2   200                     Spices and Herbs
# 2    3   300                           Baby Foods
# 3    4   400                        Fats and Oils
# 4    5   500                     Poultry Products
# 5    6   600           Soups, Sauces, and Gravies
# 6    7   700          Sausages and Luncheon Meats
# 7    8   800                    Breakfast Cereals
# 8    9   900              Fruits and Fruit Juices
# 9   10  1000                        Pork Products
# 10  11  1100    Vegetables and Vegetable Products
# 11  12  1200                Nut and Seed Products
# 12  13  1300                        Beef Products
# 13  14  1400                            Beverages
# 14  15  1500       Finfish and Shellfish Products
# 15  16  1600          Legumes and Legume Products
# 16  17  1700        Lamb, Veal, and Game Products
# 17  18  1800                       Baked Products
# ...

# %%
foods = read_csv('food.csv')

# %%
foods['data_type'].unique()
# Out:
# array(['branded_food', 'sample_food', 'sub_sample_food',
#        'market_acquisition', 'foundation_food',
#        'agricultural_acquisition', 'survey_fndds_food', 'sr_legacy_food'],
#       dtype=object)

# %%
foods[foods['data_type']=='sample_food']
# Out:
#         fdc_id    data_type  \
# 299000  321506  sample_food
# 299001  321512  sample_food
# 299002  321521  sample_food
# 299003  321528  sample_food
# 299005  321538  sample_food
# ...        ...          ...
# 318472  329279  sample_food
# 318473  329295  sample_food
# 318474  329316  sample_food
# 318475  329331  sample_food
# 318476  329346  sample_food
#
#                                               description  food_category_id  \
# 299000            BEANS, SNAP, CANNED, DRAINED, DEL MONTE              11.0
# 299001            BEANS, SNAP, CANNED, DRAINED, DEL MONTE              11.0
# 299002            BEANS, SNAP, CANNED, DRAINED, DEL MONTE              11.0
# 299003            BEANS, SNAP, CANNED, DRAINED, DEL MONTE              11.0
# 299005            BEANS, SNAP, CANNED, DRAINED, DEL MONTE              11.0
# ...                                                   ...               ...
# 318472  Cheese, string (low-moisture, part-skim mozzar...               1.0
# ...

# %%
foods[foods['data_type']=='sub_sample_food']
# Out:
#         fdc_id        data_type  \
# 299004  321535  sub_sample_food
# 299006  321545  sub_sample_food
# 299015  322896  sub_sample_food
# 299016  322897  sub_sample_food
# 299018  322906  sub_sample_food
# ...        ...              ...
# 318654  333131  sub_sample_food
# 318655  333132  sub_sample_food
# 318656  333178  sub_sample_food
# 318657  333179  sub_sample_food
# 318658  333180  sub_sample_food
#
#                                               description  food_category_id  \
# 299004                          Beans snap canned drained              11.0
# 299006                          Beans snap canned drained              11.0
# 299015                                      Hot dogs beef               7.0
# 299016                                      Hot dogs beef               7.0
# 299018                                      Hot dogs beef               7.0
# ...                                                   ...               ...
# ...
