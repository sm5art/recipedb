# %%
import sys
sys.path.insert(0, "/Users/artur/workspace/recipedb")

# %%
from recipedb.db import get_db
import functools

# %%
db = get_db()

# %%
exs = db.allrecipes.find({"error":{"$eq":None}})

# %%
NUM_EXAMPLES = 30000
exs_recipes = list(map(lambda x: next(exs), range(NUM_EXAMPLES))) # grab the next NUM_EXAMPLES from cursor above

# %%
def write_list_file(file, lst):
    with open(file, "w+") as f:
        f.writelines(map(lambda x: "%s\n"%x,list(lst)))

# %%
# Lets try simple counts first and then lets see if tf idf improves it, first step is finding common ingredients
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
# add up all the ingredients into long corpus of ingredients
corpus = functools.reduce(lambda a,b: a+b, list(map(lambda x: x['data']['ingredients'], exs_recipes)))

# %%
vectorizer = CountVectorizer(analyzer='word',ngram_range=(1,5),)
tfidf = TfidfVectorizer(ngram_range=(1,5),)

# %%
vectorizer.fit(corpus)
tfidf.fit(corpus)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 5), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
write_list_file('gram.txt', vectorizer.get_feature_names())

# %%
write_list_file("tfidf.txt", tfidf.get_feature_names())

# %%
def read_list_file(file):
    with open(file, "r") as f:
        data = f.readlines()
        return list(map(lambda x: x.strip(), data))

# %%
data = read_list_file('gram.txt')

# %%
# run through the list and remove the ones that occur in other ones
def remove_occurences(lst):
    i = 0
    lst = list(lst)
    while (len(lst)-1-i) > 0:
        current = lst[i] 
        nxt = lst[i+1]
        if current in nxt:
            lst.remove(current)
        else:
            i += 1
    return lst

# %%
cleaned_data = remove_occurences(data)

# %%
len(cleaned_data)/NUM_EXAMPLES
# Out:
# 2.6674

# %%
counts = {}

for string in cleaned_data:
    for part in string.split():
        if counts.get(part) is None:
            counts[part] = 0
        counts[part] += 1

# %%
counts
# Out:
# {'10': 395,
#  'inch': 574,
#  'flour': 203,
#  'tortillas': 49,
#  '12': 375,
#  '25': 121,
#  'ounce': 3285,
#  'can': 1291,
#  'beef': 462,
#  'condensed': 157,
#  '75': 87,
#  'beefy': 5,
#  'chicken': 234,
#  'cream': 448,
#  'fat': 255,
#  'low': 111,
#  'milk': 297,
#  'new': 47,
#  'tomato': 263,
#  'water': 220,
#  'cans': 645,
#  'loaf': 101,
#  'day': 29,
#  'package': 1366,
#  'frozen': 644,
#  'prepared': 139,
#  'almonds': 71,
#  'apples': 147,
#  'peeled': 995,
#  'cored': 218,
#  'and': 2906,
#  'baking': 81,
#  'potatoes': 421,
#  'cut': 1120,
#  'bananas': 45,
#  'mashed': 117,
#  'frankfurters': 23,
#  'black': 278,
#  'olives': 228,
#  'peppercorns': 31,
#  'blue': 33,
#  'crab': 47,
#  'claws': 4,
#  'steamed': 23,
#  'buttery': 28,
#  'round': 153,
#  'crackers': 117,
#  'crushed': 408,
#  'caramels': 16,
#  'carrots': 165,
#  'into': 1192,
#  'sliced': 1466,
#  'cherries': 115,
#  'with': 547,
#  'stems': 85,
#  'cherry': 88,
#  'tomatoes': 487,
#  'halved': 277,
#  'chocolate': 374,
#  'covered': 40,
#  'almond': 35,
#  'buttercrunch': 9,
#  'mint': 69,
#  'candies': 32,
#  'coarsely': 171,
#  'sandwich': 29,
#  'cookies': 64,
#  'cinnamon': 71,
#  'sticks': 24,
#  'cloves': 67,
#  'garlic': 258,
#  'chopped': 2005,
#  'minced': 365,
#  'roasted': 81,
#  'cubes': 100,
#  'bouillon': 36,
#  'crumbled': 157,
#  'ice': 89,
#  'cucumber': 61,
#  'cups': 1205,
#  'all': 47,
#  'purpose': 54,
#  'broth': 126,
#  'stock': 43,
#  'bread': 558,
#  'dried': 481,
#  'crumbs': 117,
#  'dry': 505,
#  'powder': 235,
#  'fresh': 1050,
#  'large': 437,
#  'chunks': 98,
#  'of': 171,
#  'mixed': 125,
#  'salad': 172,
#  'greens': 51,
#  'popped': 12,
#  'popcorn': 21,
#  'tart': 31,
#  'apple': 184,
#  'white': 473,
#  'zucchini': 77,
#  'dashes': 11,
#  'hot': 211,
#  'pepper': 580,
#  'sauce': 579,
#  'drops': 24,
#  'food': 127,
#  'coloring': 40,
#  'green': 608,
#  'red': 555,
#  'ears': 11,
#  'corn': 341,
#  'egg': 119,
#  'yolks': 11,
#  'eggs': 59,
#  'beaten': 47,
#  'separated': 25,
#  'firm': 56,
#  'ripe': 78,
#  'peaches': 84,
#  'fluid': 422,
#  'bottle': 278,
#  'reduced': 50,
#  'worcestershire': 25,
#  'ounces': 1035,
#  'heavy': 55,
#  'skim': 31,
#  'teriyaki': 14,
#  'warm': 36,
#  'rum': 105,
#  'french': 158,
#  'style': 306,
#  'beans': 548,
#  'mushrooms': 277,
#  'quartered': 232,
#  'pitted': 197,
#  'small': 377,
#  'cobs': 5,
#  'granny': 18,
#  'smith': 28,
#  'greek': 12,
#  'bell': 249,
#  'peppers': 387,
#  'hamburger': 8,
#  'buns': 15,
#  'hard': 32,
#  'cooked': 418,
#  'hershey': 10,
#  'hugs': 4,
#  'chocolates': 13,
#  'melted': 98,
#  'dog': 8,
#  'dogs': 14,
#  'angel': 22,
#  'cake': 80,
#  'double': 15,
#  'crust': 53,
#  'pie': 92,
#  'warmed': 10,
#  'herb': 78,
#  'pan': 22,
#  'sponge': 7,
#  'tube': 3,
#  'whole': 365,
#  'wheat': 150,
#  'jalapeno': 138,
#  'chile': 213,
#  'jumbo': 21,
#  'shrimp': 241,
#  'kaffir': 2,
#  'lime': 113,
#  'leaves': 216,
#  'torn': 137,
#  'kalamata': 34,
#  'scrubbed': 47,
#  'marshmallows': 38,
#  'russet': 21,
#  'heads': 37,
#  'off': 10,
#  'strawberries': 114,
#  'cabbage': 128,
#  'basil': 134,
#  'spinach': 209,
#  'lettuce': 101,
#  'lemons': 9,
#  'links': 41,
#  'smoked': 100,
#  'sausage': 224,
#  'macintosh': 7,
#  'manicotti': 10,
#  'shells': 86,
#  'medium': 189,
#  'taco': 26,
#  'heated': 15,
#  'bag': 24,
#  'spicy': 30,
#  'rib': 30,
#  'eye': 36,
#  'artichoke': 54,
#  'hearts': 77,
#  'asparagus': 65,
#  'tips': 21,
#  'bamboo': 9,
#  'shoots': 11,
#  'consomme': 15,
#  'gravy': 58,
#  'canned': 218,
#  'coconut': 119,
#  'onion': 391,
#  'vegetable': 141,
#  'diced': 798,
#  'enchilada': 27,
#  'clams': 39,
#  'vegetables': 43,
#  'mung': 9,
#  'bean': 61,
#  'mushroom': 64,
#  'drained': 1000,
#  'pina': 14,
#  'colada': 14,
#  'refrigerated': 82,
#  'biscuit': 39,
#  'buttermilk': 48,
#  'crescent': 17,
#  'pizza': 51,
#  'turkey': 201,
#  'baby': 102,
#  'kernel': 50,
#  'brown': 149,
#  'strawberry': 76,
#  'container': 131,
#  'alfredo': 16,
#  'raw': 58,
#  'oysters': 38,
#  'thick': 141,
#  'jar': 300,
#  'jelly': 29,
#  'maraschino': 52,
#  'pineapple': 227,
#  'fruit': 151,
#  'or': 780,
#  'jars': 83,
#  'mustard': 137,
#  'mayonnaise': 42,
#  'marbled': 3,
#  'bear': 9,
#  'shaped': 12,
#  'broad': 7,
#  'romaine': 25,
#  'chips': 156,
#  'noodles': 166,
#  'factory': 4,
#  'washed': 96,
#  'broccoli': 97,
#  'english': 32,
#  'lima': 26,
#  'okra': 23,
#  'peas': 141,
#  'raspberries': 29,
#  'sweetened': 103,
#  'mini': 34,
#  'cheese': 1132,
#  'twist': 14,
#  'miniature': 19,
#  'peanut': 70,
#  'butter': 204,
#  'pita': 17,
#  'plain': 56,
#  'couscous': 19,
#  'pre': 11,
#  'rainbow': 20,
#  'colored': 36,
#  'saltine': 22,
#  'soft': 60,
#  'silken': 16,
#  'rinsed': 378,
#  'succotash': 4,
#  'thin': 151,
#  'vanilla': 146,
#  'packages': 363,
#  'brussels': 13,
#  'turnip': 14,
#  'matzo': 16,
#  'pretzels': 32,
#  'puff': 23,
#  'pastry': 50,
#  'rock': 8,
#  'lobster': 41,
#  'tails': 49,
#  'squares': 58,
#  'semisweet': 45,
#  'trout': 15,
#  'dressed': 8,
#  'filet': 18,
#  'sirloin': 111,
#  'steak': 173,
#  'button': 25,
#  'cashew': 13,
#  'pieces': 202,
#  'clean': 7,
#  'dark': 68,
#  'beer': 89,
#  'processed': 120,
#  'american': 57,
#  'fettuccini': 20,
#  'extra': 59,
#  'sharp': 61,
#  'cheddar': 174,
#  'pasta': 384,
#  'linguine': 22,
#  'thinly': 315,
#  'trimmed': 165,
#  'fusilli': 20,
#  'grape': 55,
#  'ketchup': 16,
#  'lasagna': 31,
#  'mozzarella': 91,
#  'thickly': 25,
#  'orange': 229,
#  'marmalade': 11,
#  'pecans': 55,
#  'peppercorn': 3,
#  'ranch': 46,
#  'scallops': 27,
#  'seashell': 28,
#  'shredded': 486,
#  'monterey': 52,
#  'jack': 71,
#  'swiss': 55,
#  'deveined': 108,
#  'salmon': 90,
#  'sour': 102,
#  'stemmed': 36,
#  'toasted': 166,
#  'oat': 15,
#  'cereal': 107,
#  'uncooked': 181,
#  'pepperoncini': 16,
#  'pods': 20,
#  'in': 308,
#  'cardamom': 22,
#  'cubed': 483,
#  'pound': 764,
#  'goose': 13,
#  'prime': 4,
#  'roast': 112,
#  'skinned': 20,
#  'neck': 28,
#  'pounds': 478,
#  'cod': 30,
#  'beets': 68,
#  'macaroni': 70,
#  'mussels': 14,
#  'cleaned': 85,
#  'radishes': 15,
#  'seeded': 284,
#  'chili': 125,
#  'pounded': 21,
#  'shelled': 54,
#  'slices': 280,
#  'bacon': 109,
#  'old': 54,
#  'italian': 224,
#  'provolone': 31,
#  'spears': 17,
#  'diagonally': 35,
#  'sprigs': 27,
#  'cilantro': 81,
#  'stalks': 28,
#  'celery': 144,
#  'sweet': 288,
#  'tablespoons': 718,
#  'balsamic': 22,
#  'vinegar': 138,
#  'parsley': 118,
#  'cold': 63,
#  'cornstarch': 10,
#  'margarine': 53,
#  'shortening': 21,
#  'unsalted': 51,
#  'chilled': 152,
#  'sugar': 233,
#  'teaspoons': 309,
#  'ground': 380,
#  'to': 391,
#  'each': 30,
#  'tomatillos': 13,
#  'husked': 27,
#  'wafers': 24,
#  'seeds': 115,
#  'wide': 30,
#  '100': 13,
#  'degrees': 58,
#  '38': 6,
#  'pure': 8,
#  'pumpkin': 72,
#  '110': 20,
#  '105': 7,
#  '115': 7,
#  '11': 45,
#  'juice': 551,
#  'creamed': 35,
#  'lychee': 4,
#  'mandarin': 39,
#  'oranges': 56,
#  'mexican': 44,
#  'peach': 64,
#  'nectar': 18,
#  'niblet': 5,
#  'vacuum': 4,
#  'packed': 95,
#  'lychees': 5,
#  'breadstick': 5,
#  'containers': 39,
#  'butterscotch': 24,
#  'fudge': 22,
#  'stripe': 5,
#  'softened': 112,
#  '45': 10,
#  'divided': 368,
#  'anaheim': 5,
#  'charred': 5,
#  'tamales': 6,
#  'crabs': 3,
#  'cannelloni': 5,
#  'cannoli': 2,
#  'boiling': 28,
#  'brewed': 37,
#  'coffee': 98,
#  'sifted': 30,
#  'confectioners': 46,
#  'bran': 24,
#  'dates': 16,
#  'yellow': 145,
#  'whites': 17,
#  'optional': 689,
#  'bottles': 84,
#  'cola': 18,
#  'evaporated': 36,
#  'nestle': 8,
#  'passion': 17,
#  'jiggers': 61,
#  'vodka': 55,
#  '190': 8,
#  'proof': 19,
#  'cranberry': 66,
#  'raspberry': 114,
#  'gin': 19,
#  'irish': 43,
#  'tequila': 27,
#  'measure': 5,
#  'based': 35,
#  'rolls': 42,
#  'lemon': 241,
#  'wedges': 85,
#  'potstickers': 4,
#  'onions': 279,
#  'boiled': 28,
#  'hoagie': 4,
#  'baked': 62,
#  'crusts': 52,
#  'square': 23,
#  'spring': 11,
#  'roll': 35,
#  'lamb': 60,
#  'chops': 11,
#  'tiger': 10,
#  'prawns': 20,
#  'no': 12,
#  'boil': 15,
#  'cocktail': 73,
#  'box': 3,
#  'albacore': 13,
#  'tuna': 60,
#  'corned': 44,
#  'lemonade': 55,
#  'peanuts': 72,
#  'poppyseed': 8,
#  'filling': 52,
#  'solid': 11,
#  'paste': 104,
#  'flavor': 49,
#  'whipped': 89,
#  'curd': 26,
#  'shucked': 23,
#  'fillets': 146,
#  'sole': 4,
#  'apricot': 49,
#  'jam': 29,
#  'preserves': 47,
#  'caramel': 28,
#  'topping': 78,
#  'honey': 40,
#  'mango': 45,
#  'chutney': 19,
#  'marinated': 29,
#  'pickled': 37,
#  'hair': 11,
#  'barley': 32,
#  'bow': 18,
#  'tie': 17,
#  'breakfast': 19,
#  'muffin': 16,
#  'cranberries': 69,
#  'crispy': 29,
#  'rice': 245,
#  'muffins': 7,
#  'farfalle': 20,
#  'tofu': 72,
#  'burger': 19,
#  'dinner': 29,
#  'vegetarian': 62,
#  'seasoned': 87,
#  'imitation': 35,
#  'crabmeat': 80,
#  'linguini': 11,
#  'candy': 78,
#  'miso': 14,
#  'soup': 192,
#  'oyster': 27,
#  'penne': 18,
#  'process': 21,
#  'quorn': 4,
#  'rotini': 32,
#  'corkscrew': 9,
#  'semi': 24,
#  'textured': 12,
#  'tortilla': 46,
#  'elbow': 30,
#  'unseasoned': 5,
#  'ladyfingers': 10,
#  'wonton': 11,
#  'wrappers': 31,
#  'bittersweet': 12,
#  'german': 12,
#  'confection': 5,
#  'brie': 16,
#  'rind': 11,
#  'flaked': 67,
#  'cottage': 69,
#  'feta': 44,
#  'deli': 23,
#  'apricots': 29,
#  'fettuccine': 14,
#  'flank': 18,
#  'kernels': 46,
#  'goat': 19,
#  'meat': 166,
#  'mild': 38,
#  'spanish': 29,
#  'ricotta': 27,
#  'rotelle': 9,
#  'sashimi': 4,
#  'grade': 5,
#  'sauerkraut': 53,
#  'spaghetti': 73,
#  'broken': 106,
#  'snow': 21,
#  'tri': 31,
#  'color': 23,
#  'vermicelli': 10,
#  'ziti': 14,
#  'pimento': 67,
#  'stuffed': 30,
#  'pockets': 4,
#  'plums': 12,
#  'roma': 33,
#  'plum': 54,
#  'sheets': 18,
#  'phyllo': 22,
#  'dough': 83,
#  'skewers': 5,
#  'fluffy': 3,
#  'raisin': 14,
#  'breads': 13,
#  'zucchinis': 13,
#  'squid': 7,
#  'strips': 152,
#  'liqueur': 185,
#  'yukon': 11,
#  'gold': 29,
#  '120': 5,
#  '130': 5,
#  '50': 14,
#  '13': 15,
#  'brandy': 42,
#  'cornbread': 15,
#  'flavored': 484,
#  'envelope': 30,
#  'unsweetened': 106,
#  'nacho': 15,
#  '14': 141,
#  'prune': 6,
#  'so': 3,
#  'graham': 37,
#  'sprouts': 44,
#  'stewed': 64,
#  'eagle': 4,
#  'brand': 5,
#  'free': 159,
#  'great': 24,
#  'northern': 22,
#  'lentils': 37,
#  'light': 123,
#  'sodium': 52,
#  'nonfat': 52,
#  'petite': 14,
#  'pinto': 28,
#  'tiny': 19,
#  'wax': 18,
#  'kidney': 81,
#  'marinara': 14,
#  'coated': 31,
#  'individually': 10,
#  'wrapped': 17,
#  'won': 12,
#  'ton': 10,
#  'bar': 12,
#  'spiral': 27,
#  'tail': 5,
#  'prunes': 27,
#  'quarts': 56,
#  'ginger': 121,
#  'root': 78,
#  '15': 196,
#  'mixture': 14,
#  'soaked': 44,
#  'overnight': 15,
#  'mix': 558,
#  'gingersnap': 9,
#  'gingersnaps': 2,
#  'halves': 54,
#  'eyed': 20,
#  'blueberries': 31,
#  'cannellini': 18,
#  'chickpeas': 29,
#  'garbanzo': 45,
#  'without': 44,
#  'fava': 15,
#  'grated': 220,
#  'libby': 4,
#  'navy': 16,
#  'pear': 19,
#  'pears': 39,
#  'pigeon': 8,
#  'tidbits': 13,
#  'pork': 80,
#  'puree': 52,
#  'refried': 25,
#  'shoe': 4,
#  'peg': 5,
#  'sloppy': 7,
#  'joe': 9,
#  'pack': 13,
#  'straw': 5,
#  'three': 6,
#  'hominy': 12,
#  'pink': 15,
#  'part': 16,
#  'pretzel': 15,
#  'digestive': 3,
#  'biscuits': 14,
#  'dip': 33,
#  'pudding': 78,
#  'charcoal': 8,
#  'briquets': 4,
#  'rods': 3,
#  'pistachios': 6,
#  'ham': 75,
#  'pepperoni': 44,
#  'hulled': 22,
#  'tea': 50,
#  'bags': 15,
#  'thai': 17,
#  'chiles': 57,
#  '151': 9,
#  '16': 403,
#  'figs': 9,
#  'non': 56,
#  'dairy': 30,
#  'cracker': 28,
#  'unwrapped': 15,
#  'bars': 35,
#  'cider': 37,
#  'catalina': 9,
#  'creamy': 50,
#  'dressing': 167,
#  'seasoning': 210,
#  'salt': 168,
#  'thousand': 12,
#  'island': 14,
#  'caesar': 11,
#  'wine': 176,
#  'zesty': 8,
#  'squeezed': 25,
#  'blueberry': 13,
#  'syrup': 150,
#  'preferably': 16,
#  'dr': 4,
#  'jellied': 4,
#  'organic': 9,
#  'bing': 5,
#  'flaky': 5,
#  'berry': 12,
#  'instant': 191,
#  'applesauce': 22,
#  'chunky': 23,
#  'salsa': 53,
#  'dill': 91,
#  'crunchy': 9,
#  'pickles': 57,
#  'nopales': 4,
#  'picante': 8,
#  'acini': 6,
#  'di': 7,
#  'bologna': 9,
#  'coleslaw': 15,
#  'sausages': 14,
#  'ditalini': 8,
#  'cauliflower': 53,
#  'hash': 31,
#  'meatballs': 10,
#  'pierogies': 9,
#  'potato': 133,
#  'shoepeg': 5,
#  'striped': 5,
#  'garden': 4,
#  'kielbasa': 44,
#  'little': 7,
#  'smokie': 8,
#  'mostaccioli': 5,
#  'rigatoni': 6,
#  'shell': 41,
#  'partially': 29,
#  'orzo': 9,
#  'frosting': 20,
#  'wagon': 6,
#  'wheel': 11,
#  'filled': 25,
#  'tortellini': 34,
#  'crawfish': 18,
#  'rye': 31,
#  'soba': 4,
#  'chinese': 27,
#  'rounds': 35,
#  'lean': 54,
#  'marshmallow': 14,
#  'creme': 43,
#  'oil': 223,
#  'caps': 7,
#  'gruyere': 12,
#  'pastrami': 5,
#  'gouda': 12,
#  'spaghettini': 6,
#  'sea': 29,
#  'wooden': 2,
#  '160': 5,
#  '71': 5,
#  '17': 7,
#  'burrito': 4,
#  'size': 65,
#  '18': 51,
#  'spice': 45,
#  'ready': 6,
#  'for': 300,
#  'garnish': 123,
#  'debearded': 13,
#  'barbecue': 12,
#  'barbeque': 24,
#  'glaze': 8,
#  'polenta': 11,
#  '19': 26,
#  'sandwiches': 4,
#  'lentil': 11,
#  'minestrone': 11,
#  'england': 8,
#  'brownie': 8,
#  'grain': 57,
#  'alcohol': 6,
#  '20': 77,
#  'anchovy': 27,
#  'carbonated': 52,
#  'removed': 171,
#  'shiitake': 24,
#  'steaks': 101,
#  'pearl': 25,
#  'porterhouse': 3,
#  'peppermint': 26,
#  'high': 9,
#  'quality': 5,
#  'diameter': 5,
#  'patted': 13,
#  'lobsters': 9,
#  'sun': 34,
#  'toothpicks': 2,
#  'unbaked': 11,
#  '21': 9,
#  '22': 5,
#  '23': 1,
#  '24': 57,
#  'circular': 2,
#  'clam': 26,
#  'kiwis': 5,
#  'kisses': 7,
#  'bottled': 16,
#  'top': 40,
#  'boneless': 65,
#  'skinless': 19,
#  'protein': 16,
#  'pickle': 43,
#  'unopened': 6,
#  'live': 9,
#  '24x8x1': 1,
#  'untreated': 3,
#  'cedar': 4,
#  'plank': 5,
#  'cucumbers': 38,
#  'sherry': 29,
#  'spread': 45,
#  'active': 18,
#  'hollandaise': 6,
#  'rapid': 12,
#  'rise': 13,
#  'unflavored': 27,
#  'gelatin': 24,
#  'envelopes': 11,
#  'decorator': 8,
#  'machine': 8,
#  'yeast': 69,
#  'jell': 72,
#  '26': 14,
#  '30': 21,
#  'count': 5,
#  '27': 2,
#  'bavarian': 3,
#  '28': 34,
#  '29': 16,
#  'yams': 9,
#  'ladyfinger': 5,
#  'blanched': 53,
#  'seconds': 5,
#  'seedless': 35,
#  'grapes': 42,
#  'lightly': 42,
#  'canes': 7,
#  '32': 49,
#  'ale': 28,
#  'helix': 2,
#  'snails': 3,
#  'yogurt': 122,
#  'curly': 5,
#  'southern': 21,
#  'tater': 5,
#  'tots': 6,
#  'grapefruit': 25,
#  'soda': 56,
#  '34': 1,
#  '35': 4,
#  '36': 7,
#  '40': 6,
#  '41': 1,
#  'tamarind': 16,
#  '42': 1,
#  '46': 15,
#  '48': 8,
#  '49': 2,
#  'gram': 2,
#  'unpeeled': 49,
#  'wafer': 11,
#  'walnut': 19,
#  '55': 1,
#  '57': 6,
#  '60': 6,
#  '64': 12,
#  '67': 1,
#  '69': 1,
#  '6x1': 5,
#  '72': 1,
#  'pecan': 17,
#  'golden': 23,
#  'undrained': 100,
#  'sprinkles': 20,
#  'powdered': 43,
#  'pectin': 19,
#  'packet': 35,
#  'packets': 7,
#  '750': 28,
#  'milliliter': 56,
#  'burgundy': 9,
#  'champagne': 25,
#  'chardonnay': 5,
#  'chianti': 5,
#  'duck': 23,
#  'whiskey': 59,
#  'merlot': 5,
#  'comfort': 16,
#  'sparkling': 5,
#  '96': 2,
#  '9x9': 1,
#  'cooled': 41,
#  'about': 12,
#  'thickness': 10,
#  'down': 10,
#  'absinthe': 3,
#  'according': 9,
#  'directions': 9,
#  'achiote': 5,
#  'acid': 3,
#  'pepe': 7,
#  'acorn': 5,
#  'squash': 102,
#  'added': 10,
#  'liquid': 172,
#  'adobo': 15,
#  'from': 44,
#  'chipotle': 24,
#  'taste': 206,
#  'aji': 5,
#  'amarillo': 6,
#  'alaskan': 2,
#  'king': 9,
#  'legs': 7,
#  'alcoholic': 5,
#  'alfalfa': 5,
#  'coating': 31,
#  'dredging': 5,
#  'dusting': 15,
#  'rolling': 12,
#  'as': 157,
#  'alligator': 2,
#  'allspice': 13,
#  'berries': 20,
#  'extract': 81,
#  'toffee': 17,
#  'bits': 27,
#  'heath': 5,
#  'slivered': 26,
#  'aloe': 2,
#  'vera': 3,
#  'alphabet': 3,
#  'already': 5,
#  'bagged': 5,
#  'alternate': 1,
#  'amaranth': 2,
#  'amarettini': 2,
#  'amaretto': 21,
#  'creamer': 23,
#  'amber': 4,
#  'amchoor': 2,
#  'your': 8,
#  'choice': 18,
#  'amish': 2,
#  'friendship': 3,
#  'starter': 13,
#  'see': 5,
#  'an': 5,
#  'ring': 4,
#  'ancho': 4,
#  'anchovies': 5,
#  'filets': 8,
#  'brine': 8,
#  'reserved': 133,
#  'nugget': 6,
#  'until': 9,
#  'boned': 9,
#  'reserving': 5,
#  'skin': 47,
#  'bones': 31,
#  'oatmeal': 7,
#  'butterflied': 9,
#  'thawed': 271,
#  'cartilage': 10,
#  'combination': 5,
#  'fine': 21,
#  'chunked': 5,
#  'watercress': 17,
#  'lukewarm': 16,
#  'crosswise': 9,
#  'butternut': 20,
#  'horseradish': 25,
#  'half': 105,
#  'lengthwise': 100,
#  'bite': 78,
#  'eighths': 7,
#  'dice': 27,
#  'rings': 77,
#  'matchsticks': 6,
#  'semicircles': 5,
#  'fries': 12,
#  'thirds': 12,
#  'uniform': 5,
#  'up': 10,
#  'deseeded': 7,
#  'attached': 6,
#  'peel': 75,
#  'finely': 392,
#  'frenched': 5,
#  'freshly': 40,
#  'giblets': 26,
#  ...}

# %%
counts_series = pd.Series(counts)

# %%
counts_series.sort_values(ascending=False).head(1000).to_csv('counts.csv')

# %%
with open('allrecipes_noningredient_words.txt', "r+") as f:
    annotated_data = list(map(lambda x: x.strip(), f.readlines()))

# %%
def remove_common_words(data_series):
    output = []
    for x in data_series:
        original_words = list(x.split())
        for word in x.split():
            if word in annotated_data or word.isdigit():
                original_words.remove(word)
        output.append(' '.join(original_words))
    return output

# %%
ingredients_set = set(remove_common_words(cleaned_data))

# %%
len(ingredients_set)
# Out:
# 8527

# %%
with open("ingredient_set.txt", "w+") as f:
    f.writelines(map(lambda x: "%s\n"%x,list(ingredients_set)))

# %%
ingreds = list(ingredients_set)

# %%
ingreds.sort()

# %%
# https://en.wikipedia.org/wiki/Hamming_distance distance between two strings
# a more relative hamming distance
def hamming_score(string1, string2):
    dist_counter = 0
    max_val = min(len(string1),len(string2))
    for n in range(max_val):
        if string1[n] != string2[n]:
            dist_counter += 1
    if max_val is 0:
        return 0
    return dist_counter/max_val

# %%
THRESHOLD = 0.3
ingreds = list(ingredients_set)
ingreds.sort()
duplicates = []
for i in range(len(ingreds)-1):    
    if (hamming_score(ingreds[i], ingreds[i+1])) < THRESHOLD:
        print('matched')
        print(ingreds[i])
        print(ingreds[i+1])
        duplicates.append(ingreds[i]) # add first match to duplicates
# Out:
# matched
#
# 24x8x1 untreated cedar plank
# matched
# acini di
# acini di pepe
# matched
# acini di pepe
# acini di pepe pasta
# matched
# active
# active yeast
# matched
# adobo sauce
# adobo sauce from canned chipotle
# matched
# adobo sauce from canned chipotle
# adobo sauce taste
# matched
# adobo seasoning
# adobo seasoning taste
# matched
# albacore tuna
# albacore tuna broken
# matched
# albacore tuna steaks
# albacore tuna water
# matched
# ale
# ale soda
# matched
# alfredo
# alfredo pasta
# matched
# alfredo pasta
# alfredo pasta sauce
# matched
# all purpose apples
# all purpose apples cored
# matched
# all purpose baking mix
# all purpose flour
# matched
# all purpose flour
# all purpose flour for
# matched
# all purpose flour for
# all purpose flour for coating
# matched
# all purpose flour for coating
# all purpose flour for dredging
# matched
# all purpose flour for dredging
# all purpose flour for dusting
# matched
# all purpose flour for dusting
# all purpose flour for rolling
# matched
# all purpose flour for rolling
# all purpose flour sifted
# matched
# allspice
# allspice berries
# matched
# almond buttercrunch candies
# almond buttercrunch confection
# matched
# almond liqueur
# almond oil
# matched
# almond toffee bits
# almond toffee bits heath
# matched
# almond toffee bits heath
# almond toffee bits heath bits
# matched
# almond toffee bits heath bits
# almonds
# matched
# almonds
# almonds blanched slivered
# matched
# amaretto almond
# amaretto almond liqueur
# matched
# american cheese
# american cheese broken
# matched
# american cheese broken
# american cheese your
# matched
# american cheese your
# american cheese your choice
# matched
# amish friendship bread starter
# amish friendship bread starter see
# matched
# anaheim pepper
# anaheim peppers
# matched
# anchovy filets
# anchovy fillets
# matched
# anchovy fillets
# anchovy fillets brine
# matched
# anchovy fillets brine
# anchovy fillets oil
# matched
# anchovy fillets oil
# anchovy fillets oil reserved
# matched
# anchovy fillets oil reserved
# anchovy fillets patted
# matched
# angel
# angel food
# matched
# angel food
# angel food cake
# matched
# angel food cake
# angel food cake mix
# matched
# angel hair
# angel hair pasta
# matched
# anise
# anise extract
# matched
# any color food coloring
# any color food coloring paste
# matched
# apple
# apple brandy
# matched
# apple cider
# apple cider non alcoholic
# matched
# apple cider vinegar
# apple cored
# matched
# apple juice
# apple juice concentrate
# matched
# apple peel grated
# apple pie
# matched
# apple pie
# apple pie filling
# matched
# apple room
# apple room temperature
# matched
# apple without peel
# apples
# matched
# apples
# apples cored
# matched
# apples cored
# apples cored julienned
# matched
# apricot
# apricot baby food
# matched
# apricot halves
# apricot halves juice
# matched
# apricot halves juice
# apricot jam
# matched
# apricot jam
# apricot jell
# matched
# apricot jell
# apricot jell mix
# matched
# apricot peach
# apricot peach jell
# matched
# apricot preserves
# apricots
# matched
# apricots
# apricots medium
# matched
# apricots medium
# apricots medium dice
# matched
# arbol
# arborio rice
# matched
# artichoke
# artichoke hearts
# matched
# artichoke hearts
# artichoke hearts liquid reserved
# matched
# artichoke hearts liquid reserved
# artichoke hearts mashed
# matched
# artichoke hearts mashed
# artichoke hearts water
# matched
# artichoke hearts water
# artichokes
# matched
# artificially sweetened
# artificially sweetened citrus
# matched
# artificially sweetened citrus
# artificially sweetened citrus soda
# matched
# arugula
# arugula leaves
# matched
# arugula stems
# arugula stems included
# matched
# asparagus
# asparagus liquid
# matched
# asparagus liquid
# asparagus liquid reserved
# matched
# asparagus liquid reserved
# asparagus soup
# matched
# asparagus soup
# asparagus spears
# matched
# asparagus spears
# asparagus tips
# matched
# asparagus tips
# asparagus tough ends snapped
# matched
# asparagus tough ends snapped
# asparagus tough ends snapped off
# matched
# assorted food coloring
# assorted fruit
# matched
# assorted fruit
# assorted fruit jell
# matched
# assorted fruit jell
# assorted fruit jell mix
# matched
# au gratin instant
# au gratin instant potato
# matched
# au gratin instant potato
# au gratin instant potato mix
# matched
# avocado
# avocado julienned
# matched
# avocado mashed
# avocados
# matched
# avocados
# avocados mashed
# matched
# baby
# baby carrots
# matched
# baby dill
# baby dill pickles
# matched
# baby kernel
# baby kernel corn
# matched
# baby kernel corn
# baby kernel corn liquid
# matched
# baby spinach
# baby spinach leaves
# matched
# back fin picked over
# back fin picked over for
# matched
# backbone heavy duty
# backbone heavy duty scissors
# matched
# bacon
# bacon bits
# matched
# bacon fat
# bacon for topping
# matched
# bacon half
# bacon raw
# matched
# bag high quality
# bag high quality charcoal
# matched
# bag high quality charcoal
# bag high quality charcoal briquettes
# matched
# bag nacho flavor tortilla
# bag nacho flavor tortilla chips
# matched
# bag sour cream
# bag sour cream onion
# matched
# bag spicy corn
# bag spicy corn chips
# matched
# bagel split
# bagels
# matched
# baguette
# baguette diagonal
# matched
# baguette rounds
# baguettes
# matched
# baguettes
# baguettes diagonal
# matched
# baked beans
# baked beans pork
# matched
# baked chocolate
# baked chocolate cake
# matched
# baked chocolate cake
# baked chocolate cake layers
# matched
# baking chips
# baking chocolate
# matched
# baking potato
# baking potatoes
# matched
# baking potatoes
# baking potatoes scrubbed
# matched
# baking potatoes scrubbed
# baking potatoes wedges
# matched
# baking powder
# baking soda
# matched
# baller
# balls
# matched
# balsamic vinaigrette salad dressing
# balsamic vinegar
# matched
# balsamic vinegar
# balsamic vinegar taste
# matched
# bamboo shoots
# bamboo shoots julienned
# matched
# banana
# banana broken chunks
# matched
# banana chips
# banana chunked
# matched
# banana leaf
# banana liqueur
# matched
# banana pepper
# banana pepper juice
# matched
# banana pepper juice
# banana pepper rings
# matched
# banana pepper rings
# banana peppers
# matched
# banana squash
# bananas
# matched
# bananas
# bananas bite
# matched
# bananas bite
# bananas broken chunks
# matched
# bar milk chocolate
# bar milk chocolate crispy
# matched
# barbecue sauce
# barbecue sauce your choice
# matched
# barbecue sauce your choice
# barbeque sauce
# matched
# barbeque sauce
# barbeque seasoning
# matched
# barley
# barley flakes
# matched
# barley flakes
# barley flour
# matched
# barley nugget cereal grape
# barley nugget cereal grape nuts
# matched
# barley nugget cereal grape nuts
# bars
# matched
# bars
# bars astwix
# matched
# bars baby ruth candy
# bars baby ruth candy bars
# matched
# bars chocolate coated
# bars chocolate coated caramel
# matched
# bars chocolate coated caramel
# bars chocolate coated caramel peanut
# matched
# bars chocolate covered english
# bars chocolate covered english toffee
# matched
# bars chocolate covered english toffee
# bars chocolate covered toffee
# matched
# bars chocolate covered toffee
# bars chocolate covered toffee bars
# matched
# bars dark chocolate
# bars dark chocolate candy
# matched
# bars milk chocolate covered
# bars milk chocolate covered caramel
# matched
# base
# based chili sauce
# matched
# basil
# basil cilantro
# matched
# basil leaves
# basil leaves for
# matched
# basil leaves for
# basil leaves for garnish
# matched
# basil pasta sauce
# basil pesto
# matched
# basil pesto
# basil pesto sauce
# matched
# bay leaf
# bay leaves
# matched
# bay scallops
# bay scallops raw
# matched
# bay seasoning tm
# bay seasoning tm taste
# matched
# bean
# bean bacon soup
# matched
# bean sauce
# bean soup
# matched
# bean soup
# bean soup mix
# matched
# bean sprouts
# bean sprouts for
# matched
# bean sprouts for
# bean sprouts for garnish
# matched
# bean sprouts for garnish
# beans
# matched
# beans
# beans bite sized
# matched
# beans chickpeas
# beans chickpeas mashed
# matched
# beans liquid
# beans liquid reserved
# matched
# bear shaped
# bear shaped graham
# matched
# bear shaped graham
# bear shaped graham cookies
# matched
# beaten
# beaten egg
# matched
# beef
# beef bacon drippings
# matched
# beef bouillon crumbled
# beef bouillon cube
# matched
# beef bouillon cube
# beef bouillon granules
# matched
# beef brisket
# beef brisket spice packet
# matched
# beef broth
# beef broth chicken
# matched
# beef broth chicken
# beef broth chicken broth
# matched
# beef chuck
# beef chuck roast
# matched
# beef chuck steak
# beef chuck steaks well
# matched
# beef chuck steaks well
# beef chunks
# matched
# beef cube steak
# beef cubes
# matched
# beef eye
# beef eye roast
# matched
# beef fat
# beef filet
# matched
# beef frankfurters
# beef frankfurters bite
# matched
# beef instant
# beef instant rice
# matched
# beef instant rice
# beef instant rice mix
# matched
# beef luncheon
# beef luncheon meat
# matched
# beef onion
# beef onion soup
# matched
# beef onion soup
# beef onion soup mix
# matched
# beef ramen
# beef ramen noodles
# matched
# beef rib eye
# beef rib eye steak
# matched
# beef rib eye steak
# beef rib eye steaks
# matched
# beef rib roast
# beef ribs
# matched
# beef ribs
# beef roast
# matched
# beef roast
# beef roast bone
# matched
# beef roast bone
# beef roast cubes
# matched
# beef sirloin
# beef sirloin roast
# matched
# beef sirloin roast
# beef sirloin steak
# matched
# beef sirloin steak
# beef sirloin steaks
# matched
# beef steak
# beef steak paper
# matched
# beef steak paper
# beef steaks
# matched
# beef steaks
# beef stew meat
# matched
# beef stock
# beef stock water
# matched
# beef stuffing
# beef stuffing mix
# matched
# beef tamales
# beef tamales husked
# matched
# beef tamales husked
# beef tamales husked mashed
# matched
# beef tenderloin
# beef tenderloin filet
# matched
# beef tenderloin filet
# beef tenderloin steaks
# matched
# beef tenderloin steaks
# beef tip
# matched
# beef tip
# beef tongue
# matched
# beef top sirloin
# beef top sirloin steak
# matched
# beef top sirloin steak
# beef top sirloin steaks
# matched
# beef tri tip
# beef tripe
# matched
# beef turkey
# beefy
# matched
# beefy
# beefy mushroom
# matched
# beefy mushroom
# beefy mushroom soup
# matched
# beefy mushroom soup
# beer
# matched
# beer
# beer choice
# matched
# beer room
# beer room temperature
# matched
# beet juice
# beet julienned
# matched
# beet julienned
# beets
# matched
# beets
# beets juice only
# matched
# beets juice only
# beets juice reserved
# matched
# beets liquid
# beets liquid reserved
# matched
# belgian endive
# belgian endive leaves
# matched
# belgian endive leaves
# bell
# matched
# bell
# bell pepper
# matched
# bell pepper
# bell pepper cored
# matched
# bell pepper cored
# bell pepper deseeded
# matched
# bell pepper julienned
# bell pepper rings
# matched
# bell pepper rings
# bell pepper stir
# matched
# bell pepper stir
# bell pepper stir fry
# matched
# bell pepper stir fry
# bell pepper stir fry mix
# matched
# bell pepper stir fry mix
# bell peppers
# matched
# bell peppers
# bell peppers any color stems
# matched
# bell peppers onions
# bell peppers rings
# matched
# bell peppers rings
# bell peppers roasted
# matched
# berries
# berry
# matched
# berry
# berry cranberry
# matched
# berry cranberry
# berry cranberry sauce
# matched
# bibb lettuce
# bibb lettuce leaves
# matched
# bing
# bing cherries
# matched
# bing cherries
# bing cherries juice
# matched
# bing cherries juice
# bing cherries juice reserved
# matched
# biscuit dough baked
# biscuit mix
# matched
# biscuit mix
# biscuits
# matched
# bite
# bite cheddar cheese
# matched
# bite cheddar cheese
# bite cheddar cheese crackers
# matched
# bite frosted wheat
# bite frosted wheat cereal
# matched
# bite sized
# bits
# matched
# bits
# bits brickle
# matched
# bitter ale
# bitters
# matched
# bitters
# bittersweet chocolate
# matched
# black
# black bean
# matched
# black bean
# black bean sauce
# matched
# black bean sauce
# black bean soup
# matched
# black bean soup
# black beans
# matched
# black beans
# black beans drain
# matched
# black beans drain
# black beans drain reserve
# matched
# black cherry
# black cherry jell
# matched
# black cherry jell
# black cherry jell mix
# matched
# black eyed
# black eyed peas
# matched
# black eyed peas
# black eyed peas liquid
# matched
# black pepper
# black pepper taste
# matched
# black pepper taste
# black peppercorns
# matched
# black tea bags
# black tea bags strings
# matched
# black tea bags strings
# black tea cold
# matched
# blackberries
# blackberry brandy
# matched
# blackberry brandy
# blackberry jell
# matched
# blackberry jell
# blackberry juice
# matched
# blackberry juice
# blackberry preserves
# matched
# blanched
# blanched almond halves
# matched
# blanched almond halves
# blanched almonds
# matched
# blanched slivered
# blanched slivered almonds
# matched
# blood orange rounds
# blood oranges
# matched
# blue cheese at room
# blue cheese at room temperature
# matched
# blue crab claws steamed
# blue crab crabmeat
# matched
# blueberries
# blueberries pack
# matched
# blueberries pack
# blueberries patted
# matched
# blueberry pie
# blueberry pie filling
# matched
# blueberry syrup
# blueberry yogurt
# matched
# bocconcini bite mozzarella
# bocconcini bite mozzarella balls
# matched
# boil
# boil bag
# matched
# boil bag
# boil bag rice
# matched
# boiled
# boiled according directions
# matched
# boiled eggs
# boiled eggs shells
# matched
# boiled until
# boiled until soft
# matched
# boiling potatoes
# boiling potatoes scrubbed
# matched
# boiling water
# boiling water cover
# matched
# bone turkey breast
# bone turkey breast skin
# matched
# boned reserving skin
# boned reserving skin bone
# matched
# boneless beef chuck roast
# boneless beef roast
# matched
# boneless beef roast
# boneless beef short ribs
# matched
# boneless beef top sirloin
# boneless beef top sirloin steak
# matched
# boneless butterflied leg
# boneless butterflied leg lamb
# matched
# boneless deep sea perch
# boneless deep sea perch fillets
# matched
# boneless lamb meat
# boneless lamb shoulder
# matched
# boneless new york strip
# boneless new york strip steaks
# matched
# boneless sirloin steak
# boneless sirloin tip roast
# matched
# boneless skinless chicken
# boneless skinless chicken breasts bite
# matched
# boneless skinless chicken breasts bite
# boneless skinless chicken meat
# matched
# boneless smoked bluefish
# boneless steak
# matched
# boneless turkey breast
# boneless turkey breast halves
# matched
# boneless turkey breast halves
# boneless turkey breast meat
# matched
# boneless turkey breast meat
# boneless turkey breasts
# matched
# boneless turkey breasts
# boneless turkey roast
# matched
# boneless venison roast
# bones
# matched
# bones
# bones neck shank
# matched
# bonito shavings fish
# bonito shavings fish flakes
# matched
# bosc pear
# bosc pear cored
# matched
# bosc pear cored
# bosc pears
# matched
# bouillon crumbled
# bouillon cube
# matched
# bouillon granules
# bouillon granules salt
# matched
# bourbon
# bourbon ice cream
# matched
# bow tie
# bow tie pasta
# matched
# box jumbo pasta
# box jumbo pasta shells
# matched
# bran cereal
# bran cereal raisins
# matched
# bran flakes cereal
# bran flakes cereal raisins
# matched
# brand sweetened condensed milk
# brandy
# matched
# brandy
# brandy based orange
# matched
# brandy based orange
# brandy based orange liqueur
# matched
# braunschweiger liver sausage
# braunschweiger liverwurst
# matched
# bread
# bread bite
# matched
# bread crumbled
# bread crumbs
# matched
# bread crumbs
# bread crumbs for
# matched
# bread crumbs for
# bread crumbs for topping
# matched
# bread crumbs for topping
# bread crumbs matzo
# matched
# bread crumbs matzo
# bread crumbs matzo meal
# matched
# bread crumbs seasoned
# bread crust
# matched
# bread crust
# bread crusts
# matched
# bread crusts
# bread crusts broken
# matched
# bread machine
# bread machine yeast
# matched
# bread machine yeast
# bread mix
# matched
# bread mix
# bread muffin mix
# matched
# bread stuffing
# bread stuffing mix
# matched
# bread stuffing mix
# bread stuffing mix seasoning
# matched
# bread water
# bread water squeezed
# matched
# breadcrumbs
# breads
# matched
# breads
# breads half
# matched
# breakfast mix
# breakfast sausage
# matched
# breakfast tea bags
# bream
# matched
# bream
# breast
# matched
# breast
# breast bite
# matched
# breast bite
# breast cubes
# matched
# breast cubes
# breast cutlets
# matched
# breast skin
# breasts
# matched
# breasts
# breasts bite
# matched
# brewed black tea
# brewed black tea cold
# matched
# brewed coffee
# brewed coffee cold
# matched
# brewed coffee cold
# brewed coffee cooled
# matched
# brewed coffee cooled
# brewed coffee room temperature
# matched
# brie cheese
# brie cheese coating
# matched
# brie cheese coating
# brie cheese rind
# matched
# brie cheese rind
# brie cheese rind room
# matched
# briquets
# briquettes
# matched
# broad egg
# broad egg noodles
# matched
# broccoli
# broccoli bite
# matched
# broccoli bite
# broccoli blanched
# matched
# broccoli carrots
# broccoli carrots cauliflower
# matched
# broccoli carrots cauliflower
# broccoli carrots cauliflower combination
# matched
# broccoli cheese
# broccoli cheese rice
# matched
# broccoli cheese rice
# broccoli coleslaw
# matched
# broccoli coleslaw
# broccoli coleslaw mix
# matched
# broccoli florets
# broccoli florets blanched
# matched
# broccoli florets blanched
# broccoli florets broken
# matched
# broccoli florets broken
# broccoli florets broken bite
# matched
# broccoli soup
# broccoli stalk
# matched
# broken
# broken bite
# matched
# broken bite
# broken bite sized
# matched
# broken chunks
# broken crumbs
# matched
# broken half
# broken salted pretzels
# matched
# broken spaghetti
# broken up
# matched
# broth
# broth chicken broth
# matched
# brown
# brown beer
# matched
# brown beer
# brown bread crumbled
# matched
# brown gravy
# brown gravy mix
# matched
# brown miso
# brown mustard
# matched
# brown mustard
# brown mustard seeds
# matched
# brown rice
# brown rice flour
# matched
# brown sugar
# brown sugar not
# matched
# brown sugar not
# brown sugar oatmeal
# matched
# browning sauce
# browns
# matched
# brummel brown
# brummel brown taste
# matched
# brussel sprouts
# brussels
# matched
# brussels
# brussels sprouts
# matched
# brussels sprouts
# brussels sprouts scored
# matched
# buckwheat flour
# buckwheat groats
# matched
# buffalo
# buffalo sauce
# matched
# bulb fennel
# bulb fennel cored
# matched
# bulb garlic
# bulb garlic cloves separated
# matched
# bulb only
# bulb only rings
# matched
# bulbs fennel
# bulbs fennel cored
# matched
# bulbs fennel cored
# bulbs fennel untrimmed
# matched
# bulgar
# bulgur
# matched
# bulgur
# bulgur cracked wheat
# matched
# burger
# burger crumbles
# matched
# burrito
# burrito flour
# matched
# burrito flour
# burrito flour tortillas
# matched
# but still
# but still cold follow
# matched
# butter
# butter beans
# matched
# butter flavor popcorn oil
# butter flavoring
# matched
# butter lettuce
# butter lettuce leaves
# matched
# butter margarine
# butter margarine melted
# matched
# butter margarine melted
# butter margarine softened
# matched
# butter melted
# butter melted cooled
# matched
# butter shortening
# butter shortening melted
# matched
# butter softened
# butter softened for spreading
# matched
# buttercrunch candies
# buttercrunch confection
# matched
# butterflied
# butterflied leg lamb
# matched
# butterhead
# butterhead lettuce
# matched
# buttermilk
# buttermilk at room temperature
# matched
# buttermilk biscuit dough
# buttermilk biscuit mix
# matched
# buttermilk pancake mix
# buttermilk powder
# matched
# buttermilk powder
# buttermilk room temperature
# matched
# butternut
# butternut squash
# matched
# butterscotch chips
# butterscotch pudding mix
# matched
# butterscotch topping
# buttery
# matched
# buttery
# buttery cracker crumbs
# matched
# buttery cracker crumbs
# buttery crackers
# matched
# buttery crackers
# buttery crackers crumbled
# matched
# button mushrooms
# button mushrooms thirds
# matched
# cabbage
# cabbage cored
# matched
# cabbage hearts
# cabbage leaves
# matched
# cabbage leaves
# cabbage very
# matched
# cabbage very
# cabbage wedges
# matched
# caffeinated
# caffeinated citrus
# matched
# caffeinated citrus
# caffeinated citrus soda
# matched
# caffeinated citrus soda
# caffeinated lemon
# matched
# caffeinated lemon
# caffeinated lemon lime
# matched
# caffeinated lemon lime
# caffeinated lemon lime carbonated
# matched
# cajun seasoning
# cajun seasoning taste
# matched
# cake
# cake compressed yeast
# matched
# calves liver
# calves livers
# matched
# candied cherries
# candied citron
# matched
# candied citron
# candied citron peel
# matched
# candied citron peel
# candied citrus peel
# matched
# candied mixed citrus peel
# candied mixed fruit
# matched
# candied mixed fruit
# candied mixed fruit peel
# matched
# candied pineapple
# candies
# matched
# candies
# candies rolo tm
# matched
# candies unwrapped
# candy
# matched
# candy
# candy bar broken
# matched
# candy bar broken
# candy bars
# matched
# candy coated
# candy coated chocolate
# matched
# candy coated chocolate
# candy coated chocolates
# matched
# candy coated chocolates
# candy coated milk
# matched
# candy coated milk
# candy coated milk chocolate
# matched
# candy coating melted
# candy corn
# matched
# canned
# canned artichoke
# matched
# canned artichoke
# canned artichoke hearts
# matched
# canned beets
# canned beets juice
# matched
# canned beets juice
# canned beets juice reserved
# matched
# canned chicken broth
# canned chickpeas
# matched
# canned chipotle
# canned chipotle peppers
# matched
# canned chipotle peppers
# canned chipotle peppers adobo
# matched
# canned chipotle peppers adobo
# canned chipotle peppers taste
# matched
# canned chipotle peppers taste
# canned corn
# matched
# canned corn
# canned crabmeat
# matched
# canned crabmeat
# canned cream
# matched
# canned cream
# canned cream corn
# matched
# canned grapes
# canned grated coconut
# matched
# canned grated coconut
# canned grated coconut syrup
# matched
# canned green chile
# canned green chile peppers
# matched
# canned green chile peppers
# canned green chiles
# matched
# canned green chiles
# canned green peas
# matched
# canned kernel
# canned kernel corn
# matched
# canned kernel corn
# canned kernel corn well
# matched
# canned kernel corn well
# canned kidney
# matched
# canned kidney
# canned kidney beans
# matched
# canned peach halves
# canned peaches
# matched
# canned peaches
# canned pears
# matched
# canned pears
# canned peas
# matched
# canned peas
# canned pineapple
# matched
# canned pineapple
# canned pineapple chunks
# matched
# canned pumpkin
# canned pumpkin puree
# matched
# canned red
# canned red beans
# matched
# canned salmon
# canned salmon liquid
# matched
# canned salmon liquid
# canned salmon liquid reserved
# matched
# canned shrimp
# canned shrimp drain
# matched
# canned sweet potato puree
# canned sweet potatoes
# matched
# canned tomato
# canned tomato sauce
# matched
# canned tomato sauce
# canned tomatoes
# matched
# canned tomatoes
# canned tomatoes half
# matched
# canned tomatoes half
# canned tuna
# matched
# cannellini beans
# cannellini beans liquid
# matched
# cannelloni pasta
# cannelloni pasta shells
# matched
# canning
# canning salt
# matched
# canola oil
# canola oil for frying
# matched
# canola other vegetable
# canola other vegetable oil
# matched
# cantaloupe
# cantaloupe fruit melon
# matched
# cap
# capacola sausage
# matched
# capers
# capers for garnish
# matched
# cappuccino coffee powder
# cappuccino mix
# matched
# cappuccino mix
# caps
# matched
# caramel cookie bars astwix
# caramel ice
# matched
# caramel ice
# caramel ice cream
# matched
# caramel ice cream
# caramel ice cream topping
# matched
# caramelized sugar
# caramels
# matched
# caramels
# caramels unwrapped
# matched
# caraway seed
# caraway seeds
# matched
# carbonated
# carbonated beverage
# matched
# carbonated beverage
# carbonated water
# matched
# cardamom
# cardamom bruised
# matched
# cardamom bruised
# cardamom seeds
# matched
# carp cleaned
# carp cleaned scaled
# matched
# carrot
# carrot baby food
# matched
# carrot julienned
# carrots
# matched
# carrots
# carrots canned
# matched
# carrots canned
# carrots cauliflower combination
# matched
# carrots juice
# carrots julienned
# matched
# cartilage
# cartilage shell fragments
# matched
# cashew
# cashew halves
# matched
# cashew nuts
# cashews
# matched
# casing
# casing crumbled
# matched
# catalina salad
# catalina salad dressing
# matched
# cauliflower
# cauliflower broccoli
# matched
# cauliflower broccoli
# cauliflower broken
# matched
# cauliflower broken
# cauliflower broken florets
# matched
# cauliflower florets
# cauliflower florets broken
# matched
# cauliflower florets broken
# cauliflower florets broken bite
# matched
# cauliflower separated florets
# cauliflower steamed
# matched
# cayenne pepper
# cayenne pepper taste
# matched
# celery
# celery bite
# matched
# celery root
# celery salt
# matched
# celery salt
# celery seed
# matched
# celery seed
# celery seeds
# matched
# celery seeds
# celery soup
# matched
# celery soup
# celery stalk
# matched
# celery stalk
# celery stalks
# matched
# cereal
# cereal biscuits
# matched
# cereal crumbled
# cereal crumbs
# matched
# chambord raspberry
# chambord raspberry liqueur
# matched
# champagne
# champagne vinegar
# matched
# charcoal briquets
# charcoal briquettes
# matched
# charcoal briquettes
# chard
# matched
# chard
# chard leaves
# matched
# cheddar
# cheddar cheese
# matched
# cheddar cheese
# cheddar cheese crackers
# matched
# cheddar cheese crackers
# cheddar cheese grated
# matched
# cheddar cheese grated
# cheddar cheese sauce mix
# matched
# cheddar cheese sauce mix
# cheddar cheese singles
# matched
# cheddar cheese singles
# cheddar cheese soup
# matched
# cheddar cheese soup
# cheddar cheese taste
# matched
# cheddar colby
# cheddar colby jack
# matched
# cheddar colby jack
# cheddar colby jack cheese
# matched
# cheddar monterey
# cheddar monterey cheese
# matched
# cheddar monterey cheese
# cheddar monterey cheese blend
# matched
# cheddar monterey cheese blend
# cheddar monterey jack
# matched
# cheddar monterey jack
# cheddar monterey jack cheese
# matched
# cheddar monterey jack cheese
# cheddar monterey jack cheese blend
# matched
# cheddar monterey jack cheese blend
# cheddar soy
# matched
# cheddar soy
# cheddar soy cheese
# matched
# cheese
# cheese at room temperature
# matched
# cheese chives
# cheese chunks
# matched
# cheese crackers
# cheese creamed
# matched
# cheese creamed
# cheese crumbed
# matched
# cheese crumbed
# cheese crumbled
# matched
# cheese cubes
# cheese curds
# matched
# cheese filled
# cheese filled pierogies
# matched
# cheese filled tortellini
# cheese filling
# matched
# cheese filling
# cheese food
# matched
# cheese food
# cheese food eg velveeta
# matched
# cheese food eg velveeta
# cheese food melted
# matched
# cheese food melted
# cheese food velveeta
# matched
# cheese for topping
# cheese fourths
# matched
# cheese melted
# cheese monterey jack
# matched
# cheese softened
# cheese soup
# matched
# cheese soup
# cheese spread
# matched
# cheese taste
# cheese tortellini
# matched
# cherries
# cherries garnish
# matched
# cherries juice
# cherries juice reserved
# matched
# cherries stems
# cherry
# matched
# cherry
# cherry baking chips
# matched
# cherry flavor
# cherry flavor lemon
# matched
# cherry flavor lemon
# cherry flavor lemon lime
# matched
# cherry flavor lemon lime
# cherry flavor lemon lime carbonated
# matched
# cherry garnish
# cherry jam
# matched
# cherry jam
# cherry jell
# matched
# cherry jell
# cherry jell mix
# matched
# cherry juice
# cherry juice concentrate
# matched
# cherry peppers
# cherry peppers juice
# matched
# cherry peppers juice
# cherry pie
# matched
# cherry pie
# cherry pie filling
# matched
# cherry sweetened
# cherry sweetened soft
# matched
# cherry sweetened soft
# cherry sweetened soft drink
# matched
# chestnut puree
# chestnuts
# matched
# chestnuts
# chestnuts julienned
# matched
# chestnuts julienned
# chex
# matched
# chicken
# chicken baby food
# matched
# chicken bouillon crumbled
# chicken bouillon granules
# matched
# chicken bouillon granules
# chicken bouillon granules salt
# matched
# chicken bouillon granules salt
# chicken bouillon powder
# matched
# chicken bread
# chicken bread stuffing
# matched
# chicken bread stuffing
# chicken breast
# matched
# chicken breast
# chicken breast halves
# matched
# chicken breast halves
# chicken breast meat
# matched
# chicken breast meat
# chicken breasts bite
# matched
# chicken breasts bite
# chicken broth
# matched
# chicken broth
# chicken broth needed
# matched
# chicken broth vegetable
# chicken broth vegetable broth
# matched
# chicken flavor
# chicken flavor seasoning
# matched
# chicken flavor stuffing
# chicken flavor stuffing mix
# matched
# chicken flavor stuffing mix
# chicken gravy
# matched
# chicken gravy
# chicken gravy mix
# matched
# chicken meat
# chicken mushroom soup
# matched
# chicken noodle soup
# chicken noodle soup mix
# matched
# chicken ramen
# chicken ramen noodles
# matched
# chicken recipe tenders
# chicken rice
# matched
# chicken rice
# chicken rice mix
# matched
# chicken rice mix
# chicken rice mix rice
# matched
# chicken rice mix rice
# chicken rice soup
# matched
# chicken sausage
# chicken skin
# matched
# chicken skin
# chicken soup
# matched
# chicken soup
# chicken soup base
# matched
# chicken stock
# chicken stuffing
# matched
# chicken stuffing
# chicken stuffing mix
# matched
# chicken thighs bone
# chicken thighs bone skin
# matched
# chickpea flour
# chickpea flour besan
# matched
# chickpea flour besan
# chickpeas
# matched
# chickpeas
# chickpeas garbanzo
# matched
# chickpeas garbanzo
# chickpeas garbanzo beans
# matched
# chile
# chile de
# matched
# chile de
# chile de arbol
# matched
# chile padi bird eye chiles
# chile paste
# matched
# chile paste
# chile pepper
# matched
# chile pepper
# chile pepper taste
# matched
# chile pepper taste
# chile peppers
# matched
# chile peppers
# chile peppers charred
# matched
# chile peppers liquid
# chile peppers partially
# matched
# chile peppers partially
# chile powder
# matched
# chile sauce
# chiles
# matched
# chiles
# chiles juice
# matched
# chiles stemmed
# chiles stems
# matched
# chiles taste
# chili
# matched
# chili
# chili beans
# matched
# chili beans
# chili beans liquid
# matched
# chili beans liquid
# chili beans spicy
# matched
# chili beans spicy
# chili beans spicy sauce
# matched
# chili beans spicy sauce
# chili beef
# matched
# chili beef
# chili beef soup
# matched
# chili pepper
# chili pepper flakes
# matched
# chili pepper peruvian aji
# chili peppers
# matched
# chili peppers
# chili peppers pounded seeds
# matched
# chili peppers pounded seeds
# chili powder
# matched
# chili powder
# chili powder taste
# matched
# chili seasoning
# chili seasoning mix
# matched
# chili without
# chili without beans
# matched
# chili without beans
# chilies
# matched
# chilies
# chilies crosswise thirds
# matched
# chilies for garnish
# chilis
# matched
# chinese steamed buns
# chinese wheat
# matched
# chinese wheat
# chinese wheat noodles
# matched
# chipotle chile pepper
# chipotle chiles
# matched
# chipotle pepper
# chipotle peppers
# matched
# chipotle peppers
# chipotle peppers adobo
# matched
# chipotle peppers adobo
# chipotle peppers adobo sauce
# matched
# chipotle peppers adobo sauce
# chipotle peppers taste
# matched
# chipped beef
# chips
# matched
# chips
# chips chunks
# matched
# chive onion cream
# chive onion cream cheese
# matched
# chive onion cream cheese
# chives
# matched
# chocolate
# chocolate almond liqueur
# matched
# chocolate almond liqueur
# chocolate cake
# matched
# chocolate cake
# chocolate cake crumbs
# matched
# chocolate cake crumbs
# chocolate cake layers cooled
# matched
# chocolate cake layers cooled
# chocolate cake mix
# matched
# chocolate candy bar
# chocolate candy bar broken
# matched
# chocolate candy bar broken
# chocolate candy kisses
# matched
# chocolate cereal puffs
# chocolate chip
# matched
# chocolate chip
# chocolate chip cookies
# matched
# chocolate chip ice cream
# chocolate chips
# matched
# chocolate chips
# chocolate chips melted
# matched
# chocolate cookie crumbs
# chocolate covered
# matched
# chocolate covered
# chocolate covered almond buttercrunch
# matched
# chocolate covered almond buttercrunch
# chocolate covered almond buttercrunch candies
# matched
# chocolate covered almond buttercrunch candies
# chocolate covered caramel
# matched
# chocolate covered caramel
# chocolate covered caramel candies
# matched
# chocolate covered caramel candies
# chocolate covered caramel candies rolo
# matched
# chocolate covered caramel candies rolo
# chocolate covered caramel cookie bars
# matched
# chocolate covered caramel cookie bars
# chocolate covered caramel nougat
# matched
# chocolate covered coffee bean
# chocolate covered crispy peanut
# matched
# chocolate covered crispy peanut
# chocolate covered crispy peanut butter
# matched
# chocolate covered peanut butter
# chocolate covered peanuts
# matched
# chocolate covered peanuts
# chocolate covered toffee bars
# matched
# chocolate frosting
# chocolate fudge
# matched
# chocolate fudge
# chocolate fudge frosting
# matched
# chocolate ice cream
# chocolate ice cream softened
# matched
# chocolate ice cream softened
# chocolate ice cream softened on
# matched
# chocolate ice cream softened on
# chocolate icing
# matched
# chocolate icing
# chocolate instant breakfast mix
# matched
# chocolate melted cooled
# chocolate milk
# matched
# chocolate milk
# chocolate mint candies
# matched
# chocolate mint candies
# chocolate mix
# matched
# chocolate mix
# chocolate morsels
# matched
# chocolate sandwich
# chocolate sandwich cookies
# matched
# chocolate sandwich cookies
# chocolate sandwich cookies creme
# matched
# chocolate sprinkles
# chocolate sprinkles jimmies
# matched
# chocolate sprinkles jimmies
# chocolate syrup
# matched
# chocolate syrup
# chocolate syrup taste
# matched
# chocolate wafer cookies
# chocolate wafers
# matched
# chorizo sausage
# chorizo sausage casings
# matched
# chowder
# choy
# matched
# chuck
# chuck eye steaks
# matched
# chuck roast
# chuck roast fat
# matched
# chuck steak
# chuck steaks well
# matched
# chunk chicken
# chunked
# matched
# chunked
# chunks
# matched
# chunks
# chunks juice
# matched
# chunks juice
# chunks juice reserved
# matched
# chunky pasta
# chunky pasta sauce
# matched
# cider vinegar
# cider vinegar taste
# matched
# cilantro
# cilantro for
# matched
# cilantro for
# cilantro for garnish
# matched
# cilantro leaves
# cilantro leaves for garnish
# matched
# cilantro parsley
# cilantro taste
# matched
# cinnamon
# cinnamon bear shaped
# matched
# cinnamon bear shaped
# cinnamon bear shaped graham
# matched
# cinnamon chips
# cinnamon chips melted
# matched
# cinnamon ice cream
# cinnamon oil
# matched
# cinnamon oil
# cinnamon raisin bread
# matched
# cinnamon schnapps
# cinnamon stick
# matched
# cinnamon stick
# cinnamon stick broken
# matched
# cinnamon stick broken
# cinnamon stick broken half
# matched
# cinnamon stick broken half
# cinnamon sticks
# matched
# cinnamon sticks
# cinnamon sticks garnish
# matched
# cinnamon sticks garnish
# cinnamon sugar
# matched
# clam juice
# clam juice cocktail
# matched
# clam shells
# clams
# matched
# clams
# clams cleaned
# matched
# clams juice
# clams juice reserved
# matched
# clams shell
# clams shell scrubbed
# matched
# clarified butter
# clarified butter melted
# matched
# clarified butter melted
# clarified butter vegetable oil
# matched
# clean scrubbed new red
# clean scrubbed new red potatoes
# matched
# clean spinach
# cleaned
# matched
# cleaned
# cleaned but still
# matched
# cleaned tails heads
# clear
# matched
# clear
# clear apple cider
# matched
# clear malt
# clear malt liquor
# matched
# clove garlic
# clove garlic pressed
# matched
# clove garlic pressed
# cloves
# matched
# cloves
# cloves garlic
# matched
# cloves garlic
# cloves garlic more
# matched
# cloves garlic more
# cloves garlic pressed
# matched
# cloves garlic slivered
# cloves garlic slivers
# matched
# cloves garlic slivers
# cloves garlic unpeeled
# matched
# cloves pressed garlic
# cloves roasted garlic
# matched
# coarse mustard
# coarse salt
# matched
# coarse salt
# coarse sea salt
# matched
# coarse sea salt
# coarse sea salt taste
# matched
# coated chocolate
# coated chocolates
# matched
# coating
# coating melted
# matched
# coating melted
# coating mix
# matched
# cob
# cobbler topping
# matched
# cobbler topping
# cobs
# matched
# cocktail
# cocktail fine
# matched
# cocktail sauce
# cocktail sausages
# matched
# cocoa powder
# cocoa powder for dusting
# matched
# coconut
# coconut coco
# matched
# coconut coco
# coconut coco lopez
# matched
# coconut cream
# coconut cream pudding mix
# matched
# coconut meat grated
# coconut milk
# matched
# coconut milk
# coconut pineapple juice
# matched
# coconut pineapple juice
# coconut rum
# matched
# coconut rum
# coconut syrup
# matched
# cod
# cod boned
# matched
# cod boned
# cod boned flaked
# matched
# cod fillets
# cod fish
# matched
# coffee
# coffee beans
# matched
# coffee cold
# coffee cooled
# matched
# coffee granules
# coffee granules dissolved
# matched
# coffee ice cream
# coffee ice cream softened
# matched
# coffee liqueur
# coffee liqueur tia maria
# matched
# cola
# cola carbonated
# matched
# cola carbonated
# cola carbonated beverage
# matched
# colby monterey
# colby monterey jack
# matched
# colby monterey jack
# colby monterey jack cheese
# matched
# cold water
# cold water needed
# matched
# coleslaw
# coleslaw mix
# matched
# color food coloring
# color food coloring paste
# matched
# colored rotini
# colored rotini pasta
# matched
# coloring
# coloring desired
# matched
# coloring desired
# coloring paste
# matched
# concentrate slightly
# concentrated
# matched
# concentrated
# concentrated fruit
# matched
# concentrated fruit
# concentrated fruit punch
# matched
# concentrated fruit punch
# concentrated grape
# matched
# concentrated grape
# concentrated grape juice
# matched
# concentrated grape juice
# concentrated grapefruit
# matched
# concentrated grapefruit
# concentrated grapefruit juice
# matched
# concentrated raspberry
# concentrated raspberry juice
# matched
# concentrated raspberry juice
# concentrated raspberry kiwi
# matched
# concentrated raspberry kiwi
# concentrated raspberry kiwi juice
# matched
# concentrated raspberry kiwi juice
# concentrated raspberry kiwi juice partially
# matched
# concord grape wine
# concord grapes
# matched
# condensed
# condensed bean
# matched
# condensed bean
# condensed bean bacon
# matched
# condensed bean bacon
# condensed bean bacon soup
# matched
# condensed bean bacon soup
# condensed beef
# matched
# condensed beef
# condensed beef broth
# matched
# condensed beef broth
# condensed cheddar
# matched
# condensed cheddar
# condensed cheddar cheese
# matched
# condensed cheddar cheese
# condensed cheddar cheese soup
# matched
# condensed cheddar cheese soup
# condensed cheese
# matched
# condensed cheese
# condensed cheese soup
# matched
# condensed cheese soup
# condensed chicken
# matched
# condensed chicken
# condensed chicken broth
# matched
# condensed chicken broth
# condensed chicken broth undiluted
# matched
# condensed chicken broth undiluted
# condensed chicken gumbo
# matched
# condensed chicken gumbo
# condensed chicken gumbo soup
# matched
# condensed chicken gumbo soup
# condensed chicken rice
# matched
# condensed chicken rice
# condensed chicken rice soup
# matched
# condensed chicken rice soup
# condensed cream
# matched
# condensed cream
# condensed cream broccoli
# matched
# condensed cream broccoli
# condensed cream broccoli soup
# matched
# condensed cream broccoli soup
# condensed cream celery
# matched
# condensed cream celery
# condensed cream celery soup
# matched
# condensed cream celery soup
# condensed cream cheddar
# matched
# condensed cream cheddar
# condensed cream cheddar cheese
# matched
# condensed cream cheddar cheese
# condensed cream chicken
# matched
# condensed cream chicken
# condensed cream chicken soup
# matched
# condensed cream mushroom
# condensed cream mushroom soup
# matched
# condensed cream mushroom soup
# condensed cream potato
# matched
# condensed cream potato
# condensed cream potato soup
# matched
# condensed cream potato soup
# condensed cream shrimp
# matched
# condensed cream shrimp
# condensed cream shrimp soup
# matched
# condensed cream shrimp soup
# condensed cream tomato
# matched
# condensed cream tomato
# condensed cream tomato soup
# matched
# condensed cream tomato soup
# condensed french
# matched
# condensed french
# condensed french onion
# matched
# condensed french onion
# condensed french onion soup
# matched
# condensed golden
# condensed golden mushroom
# matched
# condensed golden mushroom
# condensed golden mushroom soup
# matched
# condensed golden mushroom soup
# condensed milk
# matched
# condensed milk
# condensed mincemeat
# matched
# condensed minestrone
# condensed minestrone soup
# matched
# condensed nacho
# condensed nacho cheese
# matched
# condensed nacho cheese
# condensed nacho cheese soup
# matched
# condensed onion
# condensed onion soup
# matched
# condensed oyster
# condensed oyster stew
# matched
# condensed tomato
# condensed tomato soup
# matched
# condensed vegetable
# condensed vegetable beef
# matched
# condensed vegetable beef
# condensed vegetable beef soup
# matched
# condensed vegetable beef soup
# condensed vegetable beef soup undiluted
# matched
# condensed vegetable beef soup undiluted
# condensed vegetable soup
# matched
# confection
# confectioners coating
# matched
# confectioners coating
# confectioners sugar
# matched
# confectioners sugar
# confectioners sugar for decoration
# matched
# confectioners sugar for decoration
# confectioners sugar for dusting
# matched
# confectioners sugar for dusting
# confectioners sugar for rolling
# matched
# confectioners sugar for rolling
# confectioners sugar needed
# matched
# confectioners sugar needed
# confectioners sugar sifted
# matched
# confectioners sugar sifted
# confectioners sugar taste
# matched
# container alfredo
# container alfredo pasta
# matched
# container alfredo pasta
# container alfredo pasta sauce
# matched
# container butter flavor
# container butter flavor popcorn
# matched
# container butter flavor popcorn
# container butter flavor popcorn oil
# matched
# container chicken
# container chicken broth
# matched
# container chocolate
# container chocolate frosting
# matched
# container cottage cheese
# container cottage cheese creamed
# matched
# container cottage cheese creamed
# container curd
# matched
# container curd
# container curd cottage
# matched
# container curd cottage
# container curd cottage cheese
# matched
# container fat free
# container fat free sour
# matched
# container fat free sour
# container fat free sour cream
# matched
# container fat free sour cream
# container fat free whipped
# matched
# container firm tofu
# container fruit
# matched
# container fruit
# container fruit cream
# matched
# container fruit cream
# container fruit cream cheese
# matched
# container fruit cream cheese
# container grape
# matched
# container grape
# container grape juice
# matched
# container grape juice
# container grape juice concentrate
# matched
# container herb garlic
# container herb seasoned
# matched
# container herb seasoned
# container herb seasoned bread
# matched
# container instant chocolate
# container instant chocolate drink
# matched
# container instant chocolate drink
# container instant chocolate drink mix
# matched
# container lemon flavor yogurt
# container lemon yogurt
# matched
# container lite whipped
# container lite whipped topping
# matched
# container low fat
# container low fat cottage
# matched
# container low fat cottage
# container low fat cottage cheese
# matched
# container low fat cottage cheese
# container low fat plain
# matched
# container low fat plain
# container low fat plain yogurt
# matched
# container low fat plain yogurt
# container low fat sour
# matched
# container low fat sour
# container low fat sour cream
# matched
# container naturally strawberry
# container naturally strawberry yogurt
# matched
# container non dairy
# container non dairy whipped
# matched
# container nonfat cottage
# container nonfat cottage cheese
# matched
# container nonfat lemon yogurt
# container nonfat plain yogurt
# matched
# container nonfat plain yogurt
# container nonfat sour
# matched
# container nonfat sour
# container nonfat sour cream
# matched
# container part skim
# container part skim ricotta
# matched
# container part skim ricotta
# container part skim ricotta cheese
# matched
# container plain low fat
# container plain low fat yogurt
# matched
# container plain low fat yogurt
# container plain yogurt
# matched
# container powdered non dairy
# container powdered non dairy creamer
# matched
# container refrigerated breadstick
# container refrigerated breadstick dough
# matched
# container sharp processed cheese
# container sharp processed cheese food
# matched
# container sharp processed cheese food
# container sharp processed cheese spread
# matched
# container sour cream
# container sour cream onion
# matched
# container sour cream onion
# container sour cream room
# matched
# container sour cream room
# container sour cream room temperature
# matched
# container vanilla fat free
# container vanilla fat free yogurt
# matched
# container vanilla fat free yogurt
# container vanilla low fat
# matched
# container vanilla low fat
# container vanilla low fat yogurt
# matched
# container vanilla low fat yogurt
# container vanilla yogurt
# matched
# container whipped
# container whipped topping
# matched
# containers chicken
# containers chicken broth
# matched
# containers plain low fat
# containers plain low fat yogurt
# matched
# containers plain low fat yogurt
# containers plain non fat
# matched
# containers plain non fat
# containers plain non fat yogurt
# matched
# containers plain non fat yogurt
# containers plain yogurt
# matched
# containers refrigerated soft
# containers refrigerated soft bread
# matched
# containers refrigerated soft bread
# containers refrigerated soft bread stick
# matched
# containers sharp processed cheese
# containers sharp processed cheese food
# matched
# containers sharp processed cheese food
# containers shrimp
# matched
# containers shrimp
# containers shucked
# matched
# containers shucked
# containers shucked oysters
# matched
# containers strawberry cheesecake
# containers strawberry cheesecake yogurt
# matched
# containers whipped
# containers whipped cream
# matched
# containers whipped cream
# containers whipped cream cheese
# matched
# containers whipped cream cheese
# containers whipped cream cheese softened
# matched
# containers whipped cream cheese softened
# containers whipped topping
# matched
# converted long grain white
# converted long grain white rice
# matched
# cook serve
# cook serve butterscotch
# matched
# cook serve butterscotch
# cook serve butterscotch pudding
# matched
# cookie dough
# cookies
# matched
# cookies
# cookies biscuits
# matched
# cookies vanilla
# cookies vanilla wafers
# matched
# cookies vanilla wafers
# cookies vanilla wafers lower
# matched
# cookies vanilla wafers lower
# cookies vanilla wafers lower fat
# matched
# cooking apples cored
# cooking barley
# matched
# cooking couscous
# cooking fat
# matched
# cooking fat
# cooking grits
# matched
# cooking oats
# cooking oil
# matched
# cooking oil
# cooking sherry
# matched
# cooled riced
# cooler
# matched
# cored
# cored apple
# matched
# cored apple
# cored apples
# matched
# cored pear
# cored pears
# matched
# cored pears
# cored peel
# matched
# cored tart
# cored tart apple
# matched
# coriander
# coriander seed
# matched
# coriander seed
# coriander seeds
# matched
# corkscrew pasta
# corn
# matched
# corn
# corn bread
# matched
# corn bread
# corn bread mix
# matched
# corn bread mix
# corn bread muffin
# matched
# corn bread muffin
# corn bread muffin mix
# matched
# corn husked cleaned
# corn husks
# matched
# corn husks
# corn husks silks
# matched
# corn kernels
# corn kernels blanched
# matched
# corn kernels blanched
# corn kernels from
# matched
# corn kernels from
# corn kernels from cob
# matched
# corn liquid
# corn liquid reserved
# matched
# corn meal
# corn meal mix
# matched
# corn muffin
# corn muffin mix
# matched
# corn oat cereal
# corn oil
# matched
# corn oil
# corn oil for frying
# matched
# corn tortilla
# corn tortilla chips
# matched
# corn tortilla chips
# corn tortillas
# matched
# corn tortillas
# corn tortillas wedges
# matched
# cornbread crumbs
# cornbread mix
# matched
# corned beef
# corned beef brisket
# matched
# corned beef brisket
# corned beef brisket spice
# matched
# corned beef brisket spice
# corned beef chunks
# matched
# corned beef chunks
# corned beef hash
# matched
# cornflakes cereal
# cornflakes cereal crumbled
# matched
# cornflakes cereal crumbled
# cornflakes cereal crumbs
# matched
# cornish game hens
# cornish game hens about
# matched
# cornmeal
# cornmeal for dusting
# matched
# cornstarch
# cornstarch mixed equal
# matched
# cornstarch mixed equal
# cornstarch mixed equal parts
# matched
# cottage cheese
# cottage cheese creamed
# matched
# count
# country gravy
# matched
# country gravy
# country gravy mix
# matched
# couscous
# couscous mix
# matched
# cover
# covered almond buttercrunch candies
# matched
# covered caramel candies rolo tm
# covered caramel cookie bars
# matched
# covered caramel cookie bars
# covered caramel nougat
# matched
# covered peanut butter crumbled
# covered peanuts
# matched
# crab
# crab boil
# matched
# crab boil
# crab boil seasoning
# matched
# crab claw
# crab claw picked
# matched
# crab claw picked
# crab claw picked over
# matched
# crab meat
# crab meat flaked
# matched
# crabapples
# crabapples stems
# matched
# crabmeat
# crabmeat flaked
# matched
# crabmeat flaked
# crabmeat flaked cartilage
# matched
# crabmeat picked over
# crabmeat picked over for
# matched
# crabmeat picked over for
# crabmeat picked over for cartilage
# matched
# cracked black pepper
# cracked black pepper taste
# matched
# cracked black pepper taste
# cracked black peppercorns
# matched
# cracked wheat
# cracker
# matched
# cracker
# cracker crumbs
# matched
# cracker crumbs
# cracker crusts
# matched
# cracker squares
# crackers
# matched
# crackers
# crackers broken
# matched
# crackers choice
# crackers crackers choice
# matched
# cranberries
# cranberries picked
# matched
# cranberries picked
# cranberries picked through
# matched
# cranberries picked through
# cranberries pureed
# matched
# cranberries pureed
# cranberry
# matched
# cranberry
# cranberry apple
# matched
# cranberry apple
# cranberry apple juice
# matched
# cranberry ginger ale
# cranberry jell
# matched
# cranberry jell
# cranberry jell mix
# matched
# cranberry jell mix
# cranberry juice
# matched
# cranberry juice
# cranberry juice cocktail
# matched
# cranberry juice cocktail
# cranberry juice concentrate
# matched
# cranberry raspberry
# cranberry raspberry juice
# matched
# cranberry raspberry juice
# cranberry sauce
# matched
# crawfish
# crawfish cleaned
# matched
# cream
# cream asparagus
# matched
# cream asparagus
# cream asparagus soup
# matched
# cream cheddar cheese soup
# cream cheese
# matched
# cream cheese
# cream cheese at
# matched
# cream cheese at
# cream cheese at room
# matched
# cream cheese at room
# cream cheese at room temperature
# matched
# cream cheese chives
# cream cheese room
# matched
# cream cheese room
# cream cheese room temperature
# matched
# cream cheese room temperature
# cream cheese softened
# matched
# cream chicken
# cream chicken mushroom
# matched
# cream chicken mushroom
# cream chicken soup
# matched
# cream coconut
# cream corn
# matched
# cream corn
# cream for garnish
# matched
# cream mushroom
# cream mushroom soup
# matched
# cream onion dip
# cream onion potato
# matched
# cream sandwiches
# cream sauce
# matched
# cream soda
# cream softened on microwave defrost
# matched
# cream wheat
# cream wheat cereal
# matched
# cream whipped
# creamed
# matched
# creamed
# creamed corn
# matched
# creamed corn
# creamed cottage
# matched
# creamed cottage
# creamed cottage cheese
# matched
# creamed spinach
# creamer
# matched
# creamer
# creamer liquid
# matched
# creamy dill
# creamy dill dip
# matched
# creamy italian
# creamy italian salad
# matched
# creamy italian salad
# creamy italian salad dressing
# matched
# creamy pesto sauce
# creamy pesto sauce mix
# matched
# creamy potato
# creamy potato roasted
# matched
# creamy potato roasted
# creamy potato roasted garlic
# matched
# creamy salad
# creamy salad dressing
# matched
# creamy salad dressing
# creamy salad dressing ie fat
# matched
# creamy salad dressing ie fat
# creamy salad dressing miracle
# matched
# creamy salad dressing miracle
# creamy salad dressing miracle whip
# matched
# creme de
# creme de cacao
# matched
# creme de cacao
# creme de cacao liqueur
# matched
# creme de menthe
# creme de menthe liqueur
# matched
# creole hot pepper
# creole hot pepper marinade
# matched
# creole seasoning
# creole seasoning taste
# matched
# crescent roll dough
# crescent rolls
# matched
# crispy corn
# crispy corn cereal
# matched
# ...
# matched
# tomato sauce el
# tomato sauce mushrooms
# matched
# tomato sauce mushrooms
# tomato soup
# matched
# tomato vegetable
# tomato vegetable juice
# matched
# tomato vegetable juice
# tomato vegetable juice cocktail
# matched
# tomato wedges
# tomatoes
# matched
# tomatoes
# tomatoes basil
# matched
# tomatoes basil
# tomatoes basil oregano
# matched
# tomatoes boiling
# tomatoes cored
# matched
# tomatoes cored
# tomatoes deseeded
# matched
# tomatoes each
# tomatoes each wedges
# matched
# tomatoes grated
# tomatoes green
# matched
# tomatoes green
# tomatoes green chile
# matched
# tomatoes green chile
# tomatoes green chile peppers
# matched
# tomatoes green chile peppers
# tomatoes green chiles
# matched
# tomatoes juice
# tomatoes juice reserved
# matched
# tomatoes juice reserved
# tomatoes juiced
# matched
# tomatoes lightly
# tomatoes liquid
# matched
# tomatoes liquid
# tomatoes liquid mashed
# matched
# tomatoes medium dice
# tomatoes oil
# matched
# tomatoes oil
# tomatoes oil reserved
# matched
# tomatoes paste
# tomatoes puree
# matched
# tomatoes puree
# tomatoes pureed
# matched
# tomatoes pureed
# tomatoes pushed through
# matched
# tomatoes pushed through
# tomatoes pushed through sieve
# matched
# tomatoes softened
# tomatoes softened water
# matched
# tomatoes softened water
# tomatoes use
# matched
# tomatoes use
# tomatoes use hunt
# matched
# tomatoes use hunt
# tomatoes use hunt petite
# matched
# top sirloin
# top sirloin beef
# matched
# top sirloin beef
# top sirloin lean
# matched
# top sirloin lean
# top sirloin roast
# matched
# top sirloin roast
# top sirloin steak
# matched
# top sirloin steak
# top sirloin steak inches
# matched
# top sirloin steak inches
# top sirloin steaks
# matched
# topping
# topping cool whip
# matched
# topping cool whip
# topping mix
# matched
# topping mix
# tops
# matched
# tops
# tops separated
# matched
# tortellini
# tortellini pasta
# matched
# tortilla chips
# tortillas
# matched
# tortillas
# tortillas warmed
# matched
# tortillas warmed
# tortillas wedges each
# matched
# tri
# tri color
# matched
# tri color
# tri color pasta
# matched
# tri color pasta
# tri color spiral
# matched
# tri color spiral
# tri color spiral pasta
# matched
# tri color spiral pasta
# tri colored
# matched
# tri colored
# tri colored cheese
# matched
# tri colored cheese
# tri colored cheese filled
# matched
# tri colored cheese filled
# tri colored cheese filled tortellini
# matched
# tri colored cheese filled tortellini
# tri colored pasta
# matched
# tri colored pasta
# tri colored pasta assortment
# matched
# tri tip
# tri tip roast
# matched
# tripe
# triple berry vodka
# matched
# triple berry vodka
# triple sec
# matched
# triple sec
# triple sec liqueur
# matched
# tropical fruit
# tropical fruit jell
# matched
# tropical fruit jell
# tropical fruit jell mix
# matched
# trout cleaned
# trout cleaned tails
# matched
# trout pan
# trout pan dressed
# matched
# tube pan angel
# tube pan angel food
# matched
# tube pan angel food
# tube pan angel food cake
# matched
# tuna
# tuna broken
# matched
# tuna olive
# tuna olive oil
# matched
# tuna steak
# tuna steaks
# matched
# tuna steaks
# tuna steaks about
# matched
# turkey
# turkey bite
# matched
# turkey bite
# turkey breakfast sausage
# matched
# turkey breakfast sausage
# turkey breast
# matched
# turkey breast
# turkey breast bite
# matched
# turkey breast bite
# turkey breast cutlets
# matched
# turkey breast cutlets
# turkey breast halves
# matched
# turkey breast halves
# turkey breast meat
# matched
# turkey breast meat
# turkey breast skin
# matched
# turkey breast skin
# turkey breasts
# matched
# turkey breasts
# turkey broth
# matched
# turkey broth
# turkey browned
# matched
# turkey legs
# turkey liver
# matched
# turkey meat
# turkey neck
# matched
# turkey neck
# turkey neck giblets
# matched
# turkey neck giblets
# turkey neck giblets reserved
# matched
# turkey sausage
# turkey sausage casings
# matched
# turkey sausage link without casing
# turkey sausage links
# matched
# turkey sausage links
# turkey sausage links without
# matched
# turkey sausage links without
# turkey sausage links without casings
# matched
# turkey stock
# turkey stock pan
# matched
# turkey stock pan
# turkey stock pan drippings
# matched
# turkey tenderloins
# turkeys
# matched
# turmeric
# turmeric powder
# matched
# turmeric powder
# turmeric taste
# matched
# turnip
# turnip greens
# matched
# turnip greens
# turnip greens turnip
# matched
# turnip greens turnip
# turnips
# matched
# turnips
# turnips julienned
# matched
# unbaked deep dish pie
# unbaked deep dish pie crust
# matched
# unbaked pie crusts
# unbaked pie shells
# matched
# undiluted orange juice
# undiluted orange juice concentrate
# matched
# unflavored croutons bread cubes
# unflavored gelatin
# matched
# unflavored gelatin
# unflavored gelatin powder
# matched
# unflavored gelatin powder
# unflavored jell
# matched
# uniform
# uniform bite
# matched
# unopened live medium
# unopened live medium oysters
# matched
# unpeeled
# unpeeled apples
# matched
# unpeeled medium carrots
# unpeeled medium onions
# matched
# unpeeled scrubbed
# unpeeled shrimp
# matched
# unpeeled shrimp
# unpeeled stems
# matched
# unpopped popcorn
# unpopped popcorn kernels
# matched
# unsalted
# unsalted butter
# matched
# unsalted butter
# unsalted butter melted
# matched
# unsalted butter melted
# unsalted butter melted cooled
# matched
# unsalted butter melted cooled
# unsalted butter softened
# matched
# unsalted crunchy peanut butter
# unsalted natural peanut butter
# matched
# unsalted roasted
# unsalted roasted peanuts
# matched
# unseasoned
# unseasoned bread
# matched
# unseasoned bread
# unseasoned bread stuffing
# matched
# unseasoned bread stuffing
# unseasoned bread stuffing mix
# matched
# unsulfured apples
# unsulfured molasses
# matched
# unsweetened
# unsweetened apple juice concentrate
# matched
# unsweetened apple juice concentrate
# unsweetened applesauce
# matched
# unsweetened chocolate
# unsweetened chocolate melted cooled
# matched
# unsweetened cocoa powder
# unsweetened cocoa powder for
# matched
# unsweetened cocoa powder for
# unsweetened cocoa powder for dusting
# matched
# unsweetened cocoa powder for dusting
# unsweetened coconut
# matched
# unsweetened coconut
# unsweetened coconut cream
# matched
# unsweetened coconut cream
# unsweetened coconut milk
# matched
# unsweetened flaked coconut
# unsweetened fruit
# matched
# unsweetened fruit
# unsweetened fruit soft
# matched
# unsweetened fruit soft
# unsweetened fruit soft drink
# matched
# unsweetened fruit soft drink
# unsweetened grape soft drink mix
# matched
# unsweetened grape soft drink mix
# unsweetened lemon
# matched
# unsweetened lemon
# unsweetened lemon lime
# matched
# unsweetened lemon lime
# unsweetened lemon lime drink
# matched
# unsweetened lemon lime drink
# unsweetened lemonade
# matched
# unsweetened lemonade
# unsweetened lemonade drink
# matched
# unsweetened lemonade drink
# unsweetened lemonade drink mix
# matched
# unsweetened pineapple
# unsweetened pineapple chunks
# matched
# unsweetened pineapple chunks
# unsweetened pineapple juice
# matched
# unsweetened raspberry
# unsweetened raspberry drink
# matched
# unsweetened raspberry drink
# unsweetened raspberry drink mix
# matched
# unsweetened strawberries
# unsweetened strawberry
# matched
# unsweetened strawberry
# unsweetened strawberry drink
# matched
# unsweetened strawberry drink
# unsweetened strawberry drink mix
# matched
# up
# up chicken
# matched
# vacuum
# vacuum corn
# matched
# vanilla
# vanilla baking
# matched
# vanilla baking
# vanilla baking chips
# matched
# vanilla baking chips
# vanilla bean
# matched
# vanilla bean
# vanilla bean split scraped
# matched
# vanilla bean split scraped
# vanilla beans
# matched
# vanilla candy coating
# vanilla candy coating melted
# matched
# vanilla confectioners
# vanilla confectioners coating
# matched
# vanilla extract
# vanilla extract taste
# matched
# vanilla ice cream
# vanilla ice cream softened
# matched
# vanilla ice cream softened
# vanilla ice cream softened on
# matched
# vanilla low fat yogurt
# vanilla non dairy
# matched
# vanilla pudding
# vanilla pudding mix
# matched
# vanilla pudding mix
# vanilla pudding pie filling
# matched
# vanilla wafer cookies
# vanilla wafer crumbs
# matched
# vanilla wafer crumbs
# vanilla wafers
# matched
# vanilla wafers
# vanilla wafers crumbled
# matched
# vanilla wafers lower fat
# vanilla wafers very
# matched
# vanilla wafers very
# vanilla wafers very fine
# matched
# veal
# veal cutlets
# matched
# vegetable base
# vegetable beef soup undiluted
# matched
# vegetable bouillon
# vegetable broth
# matched
# vegetable broth
# vegetable broth stock
# matched
# vegetable cooking spray
# vegetable dip
# matched
# vegetable dip
# vegetable dip mix
# matched
# vegetable juice cocktail
# vegetable oil
# matched
# vegetable oil
# vegetable oil for deep
# matched
# vegetable oil for deep
# vegetable oil for deep frying
# matched
# vegetable oil for deep frying
# vegetable oil for frying
# matched
# vegetable soup mix
# vegetable stock
# matched
# vegetable stock
# vegetables
# matched
# vegetables
# vegetables liquid
# matched
# vegetarian
# vegetarian baked
# matched
# vegetarian baked
# vegetarian baked beans
# matched
# vegetarian baked beans
# vegetarian beef
# matched
# vegetarian beef
# vegetarian beef gimme
# matched
# vegetarian beef gimme
# vegetarian beef gimme lean
# matched
# vegetarian beef gimme lean
# vegetarian burger
# matched
# vegetarian burger
# vegetarian burger crumbles
# matched
# vegetarian burger crumbles
# vegetarian burger patties
# matched
# vegetarian burger patties
# vegetarian caesar
# matched
# vegetarian caesar
# vegetarian caesar salad
# matched
# vegetarian caesar salad
# vegetarian caesar salad dressing
# matched
# vegetarian chicken flavor seasoning
# vegetarian chicken gravy
# matched
# vegetarian chicken gravy
# vegetarian chicken gravy mix
# matched
# vegetarian chicken gravy mix
# vegetarian chili
# matched
# vegetarian fish sauce
# vegetarian hot
# matched
# vegetarian hot
# vegetarian hot dog
# matched
# vegetarian hot dog
# vegetarian hot dog links
# matched
# vegetarian hot dog links
# vegetarian hot dogs
# matched
# vegetarian refried
# vegetarian refried beans
# matched
# venison
# venison cubes
# matched
# venison ribs
# venison roast
# matched
# venison steaks
# venison stew meat
# matched
# vermouth
# very
# matched
# very
# very cold evaporated
# matched
# very cold evaporated
# very cold evaporated milk
# matched
# very fine
# very ripe banana mashed
# matched
# very ripe banana mashed
# very ripe bananas
# matched
# very ripe bananas
# very ripe bananas mashed
# matched
# vidalia onion
# vidalia onion wedged
# matched
# vidalia onion wedged
# vidalia onions
# matched
# vidalia onions
# vidalia onions wedged
# matched
# vidalia other sweet
# vidalia other sweet onion
# matched
# vinegar
# vinegar based hot pepper
# matched
# vinegar based hot pepper
# vinegar based hot pepper sauce
# matched
# wagon wheel
# wagon wheel pasta
# matched
# walnut
# walnut halves
# matched
# walnut halves
# walnut oil
# matched
# walnut oil
# walnut vinaigrette
# matched
# walnut vinaigrette
# walnuts
# matched
# walnuts
# walnuts pecans
# matched
# warm water
# warm water degrees
# matched
# wasabi paste
# wasabi paste taste
# matched
# water
# water at room temperature
# matched
# water chestnuts
# water chestnuts julienned
# matched
# water degrees
# water degrees degrees
# matched
# water squeezed out
# water squeezed out broken
# matched
# watercress
# watercress for garnish
# matched
# watercress for garnish
# watercress kind
# matched
# watercress kind
# watercress kind that
# matched
# watermelon
# watermelon flesh seeds
# matched
# watermelon flesh seeds
# watermelon rind
# matched
# watermelon rind
# watermelon syrup
# matched
# wax beans
# wax beans bite
# matched
# wedge orange garnish
# wedged
# matched
# wedged
# wedges
# matched
# wedges
# wedges each
# matched
# well
# well beaten
# matched
# wheat
# wheat baking mix
# matched
# wheat barley nugget
# wheat barley nugget cereal
# matched
# wheat bran
# wheat bread
# matched
# wheat bread
# wheat bread crumbled
# matched
# wheat bread crumbled
# wheat bread crumbs
# matched
# wheat bread crumbs
# wheat bread crusts
# matched
# wheat bread crusts
# wheat bread flour
# matched
# wheat cereal
# wheat cereal biscuits
# matched
# wheat crackers
# wheat crackers crackers
# matched
# wheat flake cereal
# wheat flake cereal crumbled
# matched
# wheat flake cereal crumbled
# wheat flour
# matched
# wheat flour
# wheat flour tortillas
# matched
# wheat germ
# wheat germ wheat
# matched
# wheat pastry flour
# wheat pastry for double
# matched
# wheat pastry for double
# wheat pastry for double crust
# matched
# wheat rotini
# wheat rotini pasta
# matched
# whip
# whip needed
# matched
# whip needed
# whip tm
# matched
# whipped
# whipped cream
# matched
# whipped cream
# whipped cream beaten stiff
# matched
# whipped cream cheese
# whipped cream cheese softened
# matched
# whipped cream for garnish
# whipped cream garnish
# matched
# whipped topping
# whipped topping cool
# matched
# whipped topping cool
# whipped topping cool whip
# matched
# whipped topping cool whip
# whipped topping mix
# matched
# whipping cream
# whipping cream whipped
# matched
# whisked until smooth
# whiskey
# matched
# whiskey
# whiskey sour mix
# matched
# white
# white albacore tuna
# matched
# white beans
# white beaten
# matched
# white bread
# white bread crust
# matched
# white bread crust
# white bread crusts
# matched
# white bread crusts
# white bread cubes
# matched
# white bread cubes
# white bread dough
# matched
# white bread dough
# white bread half
# matched
# white bread half
# white bread lightly
# matched
# white bread lightly
# white bread water
# matched
# white cake
# white cake cooled
# matched
# white cake layers
# white cake layers baked
# matched
# white cake layers baked
# white cake mix
# matched
# white cheddar cheese
# white cheese
# matched
# white cheese
# white cheese monterey
# matched
# white chocolate
# white chocolate chips
# matched
# white chocolate chips
# white chocolate coffee mix
# matched
# white chocolate coffee mix
# white chocolate liqueur
# matched
# white chocolate liqueur
# white chocolate melted
# matched
# white chocolate melted
# white chocolate pudding mix
# matched
# white cooking wine
# white corn
# matched
# white corn
# white corn syrup
# matched
# white corn syrup
# white cornmeal
# matched
# white frosting
# white frosting mix
# matched
# white grape
# white grape juice
# matched
# white kidney
# white kidney beans
# matched
# white kidney beans
# white kidney cannelini
# matched
# white kidney cannelini
# white kidney cannelini beans
# matched
# white meat
# white meat turkey
# matched
# white onion
# white onion wedges
# matched
# white onion wedges
# white onions
# matched
# white parts only
# white parts tops
# matched
# white parts tops
# white parts tops separated
# matched
# white pea beans
# white peaches
# matched
# white pepper
# white pepper taste
# matched
# white pepper taste
# white peppercorns
# matched
# white rice
# white rice flour
# matched
# white rice flour
# white rice not
# matched
# white rice not
# white rum
# matched
# white sugar
# white sugar for decoration
# matched
# white sugar for decoration
# white sugar taste
# matched
# white vinegar
# white vinegar taste
# matched
# white vinegar taste
# white wine
# matched
# white wine
# white wine champagne
# matched
# white wine champagne
# white wine champagne vinegar
# matched
# whitefish
# whites
# matched
# whites
# whites at room temperature
# matched
# whites lightly beaten
# whites stiffly beaten
# matched
# wide
# wide egg
# matched
# wide egg
# wide egg noodles
# matched
# wild rice
# wild rice mix
# matched
# wine
# wine champagne vinegar
# matched
# wine vinegar
# wine vinegar lemon juice
# matched
# without casing
# without casings
# matched
# without casings
# without oil
# matched
# without oil
# without peel
# matched
# without peel
# without shells
# matched
# without shells
# without skin
# matched
# without skin
# without tails
# matched
# won
# won ton
# matched
# won ton
# won ton wrappers
# matched
# worcestershire
# worcestershire sauce
# matched
# worcestershire sauce
# worcestershire sauce taste
# matched
# yam
# yam extract
# matched
# yam extract
# yams
# matched
# yams
# yams length wise
# matched
# yeast
# yeast extract spread
# matched
# yeast extract spread
# yeast extract spread marmite
# matched
# yeast extract spread marmite
# yeast extract spread marmite vegemite
# matched
# yellow
# yellow apple
# matched
# yellow apple
# yellow apples cored
# matched
# yellow bell pepper
# yellow bell pepper julienned
# matched
# yellow bell pepper julienned
# yellow bell peppers
# matched
# yellow cake
# yellow cake mix
# matched
# yellow chili pepper peruvian
# yellow corn
# matched
# yellow corn
# yellow cornmeal
# matched
# yellow mustard
# yellow mustard taste
# matched
# yellow onion
# yellow onion wedges
# matched
# yellow onion wedges
# yellow onions
# matched
# yellow onions
# yellow onions wedges
# matched
# yellow squash
# yellow squash julienned
# matched
# yellow wax
# yellow wax beans
# matched
# yogurt
# yogurt covered raisins
# matched
# yolk beaten water
# yolks
# matched
# yolks
# yolks beaten
# matched
# zest
# zest for garnish
# matched
# zested
# zested juiced
# matched
# zesty italian
# zesty italian dressing
# matched
# zesty italian dressing
# zesty italian salad
# matched
# zesty italian salad
# zesty italian salad dressing
# matched
# ziti
# ziti pasta
# matched
# zucchini
# zucchini chunks
# matched
# zucchini rounds
# zucchini then
# matched
# zucchini yellow
# zucchini yellow summer
# matched
# zucchini yellow summer
# zucchini yellow summer squash
# matched
# zucchini yellow summer squash
# zucchinis
# matched
# zucchinis
# zucchinis grated

# %%
cleaned_ingredients_set = list(ingredients_set)
for dupe in duplicates:
    cleaned_ingredients_set.remove(dupe)
cleaned_ingredients_set.sort()

# %%
write_list_file('ingredients_set.txt', cleaned_ingredients_set)

# %%
def term_counts(ingredients_set):
    counts = {}

    for string in ingredients_set:
        for part in string.split():
            if counts.get(part) is None:
                counts[part] = 0
            counts[part] += 1
    return counts

# %%
counts = term_counts(cleaned_ingredients_set)
counts_series = pd.Series(counts)
counts_series.sort_values(ascending=False).head(1000).to_csv('counts.csv')
