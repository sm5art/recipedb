# %%
import sys
sys.path.insert(0, "/Users/artur/workspace/recipedb")
from recipedb.db import get_db
import functools
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
db = get_db()

# %%
exs = db.allrecipes.find({"error":{"$eq":None}})

# %%
NUM_EXAMPLES = 100
exs_recipes = list(map(lambda x: next(exs), range(NUM_EXAMPLES))) # grab the next NUM_EXAMPLES from cursor above

# %%
ingreds = exs_recipes[25]['data']['ingredients']

# %%
annots = pd.read_csv('annotations.csv')
text_list =  list(annots['text'])

# %%
def match_ingredient(ingred):
    matches = list(map(lambda x: fuzz.ratio(x, ingred), text_list))
    print(max(matches))
    return annots.iloc[np.argmax(matches)]

# %%
for i in range(15, 30):
    ingreds = exs_recipes[i]['data']['ingredients']
    print("INDEX %d" % i)
    print(ingreds)
    print(list(map(lambda x:match_ingredient(x), ingreds)))
    print('\n\n')
# Out:
# INDEX 15
# ['1 (1.25 ounce) package taco seasoning mix', '1/4 cup all-purpose flour', '3 pounds venison roast', '2 teaspoons cayenne pepper, or to taste', '2 tablespoons vegetable oil', '1 1/2 cups water']
# 61
# 81
# 54
# 56
# 65
# 57
# [Unnamed: 0                                                  994
# text                                         taco seasoning mix
# class         [{'id': 'AG.01.m', 'name': 'Substances for foo...
# Name: 1888, dtype: object, Unnamed: 0                                                 2746
# text                                          all-purpose flour
# class         [{'id': 'AG.01.k', 'name': 'Flour'}, {'id': 'A...
# Name: 6, dtype: object, Unnamed: 0                                                12025
# text                                        pork shoulder roast
# class         [{'id': 'AG.01.d.05', 'name': 'Pork'}, {'id': ...
# Name: 1491, dtype: object, Unnamed: 0                                       9753
# text                           cayenne pepper mixture
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}]
# Name: 283, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                    2713
# text                                  excess water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 749, dtype: object]
#
#
#
# INDEX 16
# ['2 pounds round steak', '1 clove garlic, quartered', '2 teaspoons salt', '1 1/2 tablespoons soy sauce', '1 tablespoon tomato paste', '1 tablespoon vegetable oil', '1/2 teaspoon ground black pepper', '1/2 teaspoon dried oregano']
# 58
# 65
# 69
# 55
# 65
# 67
# 75
# 54
# [Unnamed: 0                                                10580
# text                                                pork steaks
# class         [{'id': 'AG.01.d', 'name': 'Animals for food'}...
# Name: 1492, dtype: object, Unnamed: 0                                                10739
# text                                               clove garlic
# class         [{'id': 'AG.01.h.02.e', 'name': 'Onion/leek/ga...
# Name: 446, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                 9903
# text                                       low-sodium soy sauce
# class         [{'id': 'AG.01.l.04', 'name': 'Sauce/dressing'...
# Name: 1163, dtype: object, Unnamed: 0                                                  839
# text                                               tomato paste
# class         [{'id': 'AG.01.h.02.f', 'name': 'Fruits as veg...
# Name: 1945, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                                 2164
# text                                freshly ground black pepper
# class         [{'id': 'AG.01.t.05', 'name': 'Preparation for...
# Name: 831, dtype: object, Unnamed: 0                                10861
# text                            chopped oregano
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 414, dtype: object]
#
#
#
# INDEX 17
# ['1/4 cup butter', '1 teaspoon white sugar', '1 cup hot milk', '2 tablespoons active dry yeast', '6 cups bread flour, divided', '1/2 cup white sugar', '2 eggs', '1 cup orange juice', '1 tablespoon orange zest', '1 teaspoon salt']
# 69
# 67
# 73
# 48
# 49
# 73
# 80
# 80
# 67
# 71
# [Unnamed: 0                                                11256
# text                                               cubed butter
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 631, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                                 9360
# text                                                   hot milk
# class         [{'id': 'AG.01', 'name': 'Food'}, {'id': 'AG.0...
# Name: 1014, dtype: object, Unnamed: 0                                                 8272
# text                                           carbonated water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 269, dtype: object, Unnamed: 0                                                10205
# text                                             seasoned flour
# class         [{'id': 'AG.01.j', 'name': 'Meal'}, {'id': 'AG...
# Name: 1708, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                    110
# text                                         eggs
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 733, dtype: object, Unnamed: 0                                                 2931
# text                                               orange juice
# class         [{'id': 'AG.01.ab', 'name': 'Fruit juice/squas...
# Name: 1341, dtype: object, Unnamed: 0                                       2941
# text                               grated orange zest
# class         [{'id': 'AG.01.l', 'name': 'Additive'}]
# Name: 914, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object]
#
#
#
# INDEX 18
# ['3 1/2 pounds boneless chuck roast', '2 tablespoons vegetable oil', '1 (14.5 ounce) can stewed tomatoes', '1 1/2 cups pizza sauce', '1/2 cup grated Parmesan cheese', '4 teaspoons Worcestershire sauce', '2 cloves garlic, minced', '2 teaspoons salt', '2 teaspoons dried oregano', '1/2 teaspoon ground black pepper', '1/2 pound fresh mushrooms, sliced', '3 tablespoons cornstarch', '3 tablespoons water', '1 (12 ounce) package egg noodles']
# 61
# 65
# 61
# 67
# 81
# 73
# 69
# 69
# 55
# 75
# 57
# 59
# 60
# 47
# [Unnamed: 0                                                12529
# text                                           beef chuck roast
# class         [{'id': 'AG.01.n.06', 'name': 'Meat dishes'}, ...
# Name: 124, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                                10414
# text                                            stewed tomatoes
# class         [{'id': 'AG.01.h.02.f', 'name': 'Fruits as veg...
# Name: 1841, dtype: object, Unnamed: 0                                                  192
# text                                                pizza sauce
# class         [{'id': 'AG.01.h', 'name': 'Fruit and vegetabl...
# Name: 1471, dtype: object, Unnamed: 0                                                11286
# text                                     grated parmesan cheese
# class         [{'id': 'AG.01.e.02', 'name': 'Cheese'}, {'id'...
# Name: 915, dtype: object, Unnamed: 0                                                    4
# text                                       worcestershire sauce
# class         [{'id': 'AG.01.h', 'name': 'Fruit and vegetabl...
# Name: 2082, dtype: object, Unnamed: 0                                                10739
# text                                               clove garlic
# class         [{'id': 'AG.01.h.02.e', 'name': 'Onion/leek/ga...
# Name: 446, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                10861
# text                            chopped oregano
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 414, dtype: object, Unnamed: 0                                                 2164
# text                                freshly ground black pepper
# class         [{'id': 'AG.01.t.05', 'name': 'Preparation for...
# Name: 831, dtype: object, Unnamed: 0                                                11371
# text                                    condensed mushroom soup
# class         [{'id': 'AG.01.h.02.h', 'name': 'Fungi'}, {'id...
# Name: 501, dtype: object, Unnamed: 0                                 1599
# text                                 cornstarch
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 564, dtype: object, Unnamed: 0                                                 8146
# text                                                tonic water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 1952, dtype: object, Unnamed: 0                                10005
# text                            lasagna noodles
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 1091, dtype: object]
#
#
#
# INDEX 19
# ['8 cups all-purpose flour', '4 cups shredded Cheddar cheese', '3/4 cup minced jalapeno peppers', '1/2 cup white sugar', '1 1/2 teaspoons salt', '2 cups hot water', '3 (.25 ounce) packages active dry yeast', '4 tablespoons vegetable oil']
# 83
# 83
# 78
# 73
# 61
# 72
# 48
# 65
# [Unnamed: 0                                                 2746
# text                                          all-purpose flour
# class         [{'id': 'AG.01.k', 'name': 'Flour'}, {'id': 'A...
# Name: 6, dtype: object, Unnamed: 0                                                 1150
# text                                    shredded cheddar cheese
# class         [{'id': 'AG.01.e.02', 'name': 'Cheese'}, {'id'...
# Name: 1733, dtype: object, Unnamed: 0                                       1496
# text                          canned jalapeno peppers
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}]
# Name: 256, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                  714
# text                                                  hot water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 1027, dtype: object, Unnamed: 0                                                11616
# text                                flour coated chicken breast
# class         [{'id': 'AG.01.d.02', 'name': 'Part/joint of a...
# Name: 797, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object]
#
#
#
# INDEX 20
# ['4 pounds boneless chuck roast', '2 cups water', '1 (1 ounce) package dry onion and mushroom soup mix', '1 tablespoon Worcestershire sauce', '3 potatoes, peeled and chopped', '2 stalks celery, chopped', '2 carrots, chopped']
# 67
# 67
# 52
# 72
# 51
# 51
# 56
# [Unnamed: 0                                                12529
# text                                           beef chuck roast
# class         [{'id': 'AG.01.n.06', 'name': 'Meat dishes'}, ...
# Name: 124, dtype: object, Unnamed: 0                                    2713
# text                                  excess water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 749, dtype: object, Unnamed: 0                                                 1765
# text                                         dry onion soup mix
# class         [{'id': 'AG.01.h.02.e', 'name': 'Onion/leek/ga...
# Name: 709, dtype: object, Unnamed: 0                                                    4
# text                                       worcestershire sauce
# class         [{'id': 'AG.01.h', 'name': 'Fruit and vegetabl...
# Name: 2082, dtype: object, Unnamed: 0                                                10840
# text                                              potato pieces
# class         [{'id': 'AG.01.h.02.a', 'name': 'Root vegetabl...
# Name: 1507, dtype: object, Unnamed: 0                                                 9849
# text                                                celery seed
# class         [{'id': 'AG.01.h.02.b', 'name': 'Stalk vegetab...
# Name: 287, dtype: object, Unnamed: 0                                                  133
# text                                                    carrots
# class         [{'id': 'AG.01.h.02.a', 'name': 'Root vegetabl...
# Name: 274, dtype: object]
#
#
#
# INDEX 21
# ['2 tablespoons active dry yeast', '1 teaspoon white sugar', '1/2 cup warm water', '3 1/2 cups warm water', '1/4 cup honey', '1/4 cup molasses', '1/2 cup vegetable oil', '2 eggs', '2 tablespoons lemon juice', '7 cups whole wheat flour', '1/4 cup flax seed', '1/4 cup cracked wheat', '1/4 cup sunflower seeds', '4 teaspoons salt', '4 cups bread flour']
# 48
# 67
# 71
# 65
# 56
# 67
# 76
# 80
# 67
# 83
# 69
# 54
# 79
# 69
# 62
# [Unnamed: 0                                                 8272
# text                                           carbonated water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 269, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                    5856
# text                                    warm water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 2028, dtype: object, Unnamed: 0                                    5856
# text                                    warm water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 2028, dtype: object, Unnamed: 0                                                   38
# text                                                      honey
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 998, dtype: object, Unnamed: 0                                 1191
# text                                   molasses
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 1271, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                    110
# text                                         eggs
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 733, dtype: object, Unnamed: 0                                                10829
# text                                          fresh lemon juice
# class         [{'id': 'AG.01.ab', 'name': 'Fruit juice/squas...
# Name: 824, dtype: object, Unnamed: 0                                                 2747
# text                                          whole wheat flour
# class         [{'id': 'AG.01.e', 'name': 'Dairy produce'}, {...
# Name: 2070, dtype: object, Unnamed: 0                                   2695
# text                                    flax seed
# class         [{'id': 'AF.10.i', 'name': 'Seed'}]
# Name: 788, dtype: object, Unnamed: 0                                                 9624
# text                                       cubed chicken breast
# class         [{'id': 'AG.01.d.06', 'name': 'Fowls'}, {'id':...
# Name: 633, dtype: object, Unnamed: 0                                   1528
# text                              sunflower seeds
# class         [{'id': 'AF.10.i', 'name': 'Seed'}]
# Name: 1867, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                10205
# text                                             seasoned flour
# class         [{'id': 'AG.01.j', 'name': 'Meal'}, {'id': 'AG...
# Name: 1708, dtype: object]
#
#
#
# INDEX 22
# ['1 (14.5 ounce) can French-style green beans, drained', '1 (11 ounce) can white corn, drained', '1 small onion, chopped', '1/2 green bell pepper, chopped', '1 (8 ounce) container sour cream', '1 (10.75 ounce) can condensed cream of celery soup', '1/2 cup shredded sharp Cheddar cheese', 'salt and pepper to taste', '1/2 (16 ounce) package cheese flavored crackers, crushed', '1/4 cup butter, melted']
# 42
# 48
# 55
# 72
# 51
# 47
# 73
# 62
# 42
# 56
# [Unnamed: 0                                                 3699
# text                                       mexican cheese blend
# class         [{'id': 'AG.01.e.02', 'name': 'Cheese'}, {'id'...
# Name: 1242, dtype: object, Unnamed: 0                                                 8157
# text                                     puerto rican white rum
# class         [{'id': 'AG.01.y.01', 'name': 'Intoxicating li...
# Name: 1542, dtype: object, Unnamed: 0                                         3290
# text                                        small apple
# class         [{'id': 'AG.01.h.01.c', 'name': 'Apple'}]
# Name: 1764, dtype: object, Unnamed: 0                                        136
# text                                green bell pepper
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}]
# Name: 922, dtype: object, Unnamed: 0                                                 5258
# text                                        confectioners sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 506, dtype: object, Unnamed: 0                                                11371
# text                                    condensed mushroom soup
# class         [{'id': 'AG.01.h.02.h', 'name': 'Fungi'}, {'id...
# Name: 501, dtype: object, Unnamed: 0                                                 1150
# text                                    shredded cheddar cheese
# class         [{'id': 'AG.01.e.02', 'name': 'Cheese'}, {'id'...
# Name: 1733, dtype: object, Unnamed: 0                                                11060
# text                                            steamed peppers
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}, {'id':...
# Name: 1834, dtype: object, Unnamed: 0                                                 5484
# text                                      graham cracker crumbs
# class         [{'id': 'AG.01.k', 'name': 'Flour'}, {'id': 'A...
# Name: 896, dtype: object, Unnamed: 0                                                  544
# text                                             butter mixture
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 222, dtype: object]
#
#
#
# INDEX 23
# ['2 tablespoons corn syrup', '1/2 cup butter', '1 cup packed brown sugar', '1 (1 pound) loaf French bread, sliced', '5 eggs', '1 1/2 cups milk', '1 teaspoon vanilla extract', '1/4 teaspoon salt']
# 65
# 69
# 63
# 50
# 80
# 52
# 73
# 67
# [Unnamed: 0                                                  948
# text                                           white corn syrup
# class         [{'id': 'AG.01.i', 'name': 'Corn/cereals/grain...
# Name: 2055, dtype: object, Unnamed: 0                                                11256
# text                                               cubed butter
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 631, dtype: object, Unnamed: 0                                   97
# text                                brown sugar
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 202, dtype: object, Unnamed: 0                                                 3958
# text                                        dipped bread slices
# class         [{'id': 'AG.01.n.11', 'name': 'Bread'}, {'id':...
# Name: 672, dtype: object, Unnamed: 0                                    110
# text                                         eggs
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 733, dtype: object, Unnamed: 0                                                 1559
# text                                               coconut milk
# class         [{'id': 'AG.01.e', 'name': 'Dairy produce'}, {...
# Name: 473, dtype: object, Unnamed: 0                                                  112
# text                                            vanilla extract
# class         [{'id': 'AF.12', 'name': 'Particular plants/he...
# Name: 1985, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object]
#
#
#
# INDEX 24
# ['1 1/2 pounds ground beef', '3/4 cup fresh bread crumbs', '1/2 cup chili sauce', '1 egg', '1/4 teaspoon salt', '1/4 teaspoon freshly ground black pepper', '1 cup fresh sliced mushrooms', '2 tablespoons minced onion', '1 tablespoon butter', '1 cup beef broth', '2 tablespoons water', '1 tablespoon cornstarch']
# 63
# 64
# 73
# 75
# 67
# 81
# 75
# 50
# 69
# 77
# 60
# 61
# [Unnamed: 0                                       168
# text                                     ground beef
# class         [{'id': 'AG.01.d.03', 'name': 'Beef'}]
# Name: 943, dtype: object, Unnamed: 0                                      12760
# text                               panko bread crumbs
# class         [{'id': 'AG.01.n.11', 'name': 'Bread'}]
# Name: 1365, dtype: object, Unnamed: 0                                                 1374
# text                                                chili sauce
# class         [{'id': 'AG.01.l.04', 'name': 'Sauce/dressing'...
# Name: 360, dtype: object, Unnamed: 0                                    163
# text                                          egg
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 715, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                 2164
# text                                freshly ground black pepper
# class         [{'id': 'AG.01.t.05', 'name': 'Preparation for...
# Name: 831, dtype: object, Unnamed: 0                                                11426
# text                                  reserved sliced mushrooms
# class         [{'id': 'AG.01.h.02.h', 'name': 'Fungi'}, {'id...
# Name: 1617, dtype: object, Unnamed: 0                                                 9622
# text                                         caramelized onions
# class         [{'id': 'AG.01.h.02.e', 'name': 'Onion/leek/ga...
# Name: 266, dtype: object, Unnamed: 0                                                 3337
# text                                              almond butter
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 8, dtype: object, Unnamed: 0                                                10515
# text                                                 beef broth
# class         [{'id': 'AG.01.d.03', 'name': 'Beef'}, {'id': ...
# Name: 123, dtype: object, Unnamed: 0                                                 8146
# text                                                tonic water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 1952, dtype: object, Unnamed: 0                                 1599
# text                                 cornstarch
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 564, dtype: object]
#
#
#
# INDEX 25
# ['1 cup rolled oats', '1/2 cup molasses', '1/3 cup vegetable oil', '1 teaspoon salt', '1 1/2 cups boiling water', '2 tablespoons active dry yeast', '1/2 cup lukewarm water (100 degrees F/38 degrees C)', '1 cup whole wheat flour', '5 cups bread flour', '2 eggs']
# 79
# 67
# 76
# 71
# 70
# 48
# 43
# 85
# 62
# 80
# [Unnamed: 0                                                 3331
# text                                                rolled oats
# class         [{'id': 'AG.01.i', 'name': 'Corn/cereals/grain'}]
# Name: 1643, dtype: object, Unnamed: 0                                 1191
# text                                   molasses
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 1271, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                     201
# text                                 boiling water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 163, dtype: object, Unnamed: 0                                                 8272
# text                                           carbonated water
# class         [{'id': 'AG.01.z', 'name': 'Water'}, {'id': 'A...
# Name: 269, dtype: object, Unnamed: 0                                   12782
# text                                lukewarm water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 1164, dtype: object, Unnamed: 0                                                 2747
# text                                          whole wheat flour
# class         [{'id': 'AG.01.e', 'name': 'Dairy produce'}, {...
# Name: 2070, dtype: object, Unnamed: 0                                                10205
# text                                             seasoned flour
# class         [{'id': 'AG.01.j', 'name': 'Meal'}, {'id': 'AG...
# Name: 1708, dtype: object, Unnamed: 0                                    110
# text                                         eggs
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 733, dtype: object]
#
#
#
# INDEX 26
# ['1 (4 pound) whole duck, rinsed', '1 teaspoon chopped fresh basil leaves', '1 teaspoon chopped fresh ginger root', '1 teaspoon salt', '1/2 orange, quartered', '2 cups water', '1 cup honey', '1/2 cup butter', '1 teaspoon lemon juice', '1/2 cup undiluted, thawed orange juice concentrate']
# 44
# 52
# 58
# 71
# 63
# 67
# 62
# 69
# 72
# 65
# [Unnamed: 0                                10730
# text                                cooled ribs
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 545, dtype: object, Unnamed: 0                                10368
# text                      chopped green chilies
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 405, dtype: object, Unnamed: 0                                                 2586
# text                                 freshly grated ginger root
# class         [{'id': 'AG.01.h.02.a', 'name': 'Root vegetabl...
# Name: 830, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                 8038
# text                                             orange liqueur
# class         [{'id': 'AG.01.ae.01', 'name': 'Wine-making'},...
# Name: 1346, dtype: object, Unnamed: 0                                    2713
# text                                  excess water
# class         [{'id': 'AG.01.z', 'name': 'Water'}]
# Name: 749, dtype: object, Unnamed: 0                                                   38
# text                                                      honey
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 998, dtype: object, Unnamed: 0                                                11256
# text                                               cubed butter
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 631, dtype: object, Unnamed: 0                                                10829
# text                                          fresh lemon juice
# class         [{'id': 'AG.01.ab', 'name': 'Fruit juice/squas...
# Name: 824, dtype: object, Unnamed: 0                                                 4529
# text                                   orange juice concentrate
# class         [{'id': 'AG.01.ab', 'name': 'Fruit juice/squas...
# Name: 1344, dtype: object]
#
#
#
# INDEX 27
# ['2 1/2 cups all-purpose flour', '1 teaspoon baking soda', '1 teaspoon ground cinnamon', '1 teaspoon salt', '1/2 cup packed brown sugar', '1 cup buttermilk', '1 egg', '1 teaspoon vanilla extract', '2 1/2 cups chopped fresh rhubarb', '1/2 cup chopped walnuts', '1/2 cup white sugar', '2 tablespoons butter, softened']
# 76
# 67
# 73
# 71
# 59
# 77
# 75
# 73
# 48
# 79
# 73
# 55
# [Unnamed: 0                                                 2746
# text                                          all-purpose flour
# class         [{'id': 'AG.01.k', 'name': 'Flour'}, {'id': 'A...
# Name: 6, dtype: object, Unnamed: 0                                                  572
# text                                                baking soda
# class         [{'id': 'AG.01.aa', 'name': 'Aerated/carbonate...
# Name: 85, dtype: object, Unnamed: 0                                       7557
# text                                  ground cinnamon
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}]
# Name: 949, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                   97
# text                                brown sugar
# class         [{'id': 'AG.01', 'name': 'Food'}]
# Name: 202, dtype: object, Unnamed: 0                                            2618
# text                                            buttermilk
# class         [{'id': 'AG.01.e', 'name': 'Dairy produce'}]
# Name: 230, dtype: object, Unnamed: 0                                    163
# text                                          egg
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 715, dtype: object, Unnamed: 0                                                  112
# text                                            vanilla extract
# class         [{'id': 'AF.12', 'name': 'Particular plants/he...
# Name: 1985, dtype: object, Unnamed: 0                                                 3711
# text                                     chopped dried cherries
# class         [{'id': 'AG.01.h.01.e', 'name': 'Fruit contain...
# Name: 401, dtype: object, Unnamed: 0                                       1835
# text                                  chopped walnuts
# class         [{'id': 'AG.01.h.01.f', 'name': 'Nut'}]
# Name: 423, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                                 3343
# text                                      almond butter mixture
# class         [{'id': 'AG.01.e.01', 'name': 'Butter'}, {'id'...
# Name: 9, dtype: object]
#
#
#
# INDEX 28
# ['8 ounces cream cheese', '3 ounces dried beef', '2 green onions, chopped', '1/4 teaspoon onion salt', '1 1/4 teaspoons monosodium glutamate (MSG)', '1 tablespoon Worcestershire sauce']
# 76
# 69
# 69
# 65
# 65
# 72
# [Unnamed: 0                                                 3097
# text                                      softened cream cheese
# class         [{'id': 'AG.01.e', 'name': 'Dairy produce'}, {...
# Name: 1785, dtype: object, Unnamed: 0                                      1276
# text                                      dried beef
# class         [{'id': 'AG.01.d.03', 'name': 'Beef'}]
# Name: 692, dtype: object, Unnamed: 0                                                  134
# text                                               green onions
# class         [{'id': 'AG.01.h.02.e', 'name': 'Onion/leek/ga...
# Name: 933, dtype: object, Unnamed: 0                                                 1037
# text                                             seasoning salt
# class         [{'id': 'AG.01.l', 'name': 'Additive'}, {'id':...
# Name: 1712, dtype: object, Unnamed: 0                                       1415
# text                             monosodium glutamate
# class         [{'id': 'AG.01.l', 'name': 'Additive'}]
# Name: 1273, dtype: object, Unnamed: 0                                                    4
# text                                       worcestershire sauce
# class         [{'id': 'AG.01.h', 'name': 'Fruit and vegetabl...
# Name: 2082, dtype: object]
#
#
#
# INDEX 29
# ['3 cups all-purpose flour', '2 cups white sugar', '1 teaspoon ground cinnamon', '1 teaspoon salt', '1 teaspoon baking soda', '4 eggs', '1 1/4 cups vegetable oil', '1 cup chopped pecans', '1 (10 ounce) package frozen strawberries, thawed']
# 83
# 76
# 73
# 71
# 67
# 80
# 70
# 82
# 57
# [Unnamed: 0                                                 2746
# text                                          all-purpose flour
# class         [{'id': 'AG.01.k', 'name': 'Flour'}, {'id': 'A...
# Name: 6, dtype: object, Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object, Unnamed: 0                                       7557
# text                                  ground cinnamon
# class         [{'id': 'AG.01.l.03', 'name': 'Spice'}]
# Name: 949, dtype: object, Unnamed: 0                                                 1404
# text                                              seasoned salt
# class         [{'id': 'AG.01.l.01', 'name': 'Salt'}, {'id': ...
# Name: 1710, dtype: object, Unnamed: 0                                                  572
# text                                                baking soda
# class         [{'id': 'AG.01.aa', 'name': 'Aerated/carbonate...
# Name: 85, dtype: object, Unnamed: 0                                    110
# text                                         eggs
# class         [{'id': 'AG.01.g', 'name': 'Eggs'}]
# Name: 733, dtype: object, Unnamed: 0                                        50
# text                                   vegetable oil
# class         [{'id': 'AG.01.f', 'name': 'Fat/oil'}]
# Name: 1999, dtype: object, Unnamed: 0                                       1284
# text                                   chopped pecans
# class         [{'id': 'AG.01.h.01.f', 'name': 'Nut'}]
# Name: 418, dtype: object, Unnamed: 0                                                 8154
# text                                        frozen strawberries
# class         [{'id': 'AG.01.h.01.b', 'name': 'Berry'}, {'id...
# Name: 855, dtype: object]

# %%
ingreds
# Out:
# ['1 1/4 cups all-purpose flour',
#  '1 egg',
#  '1 1/4 cups buttermilk',
#  '1/4 cup white sugar',
#  '1 teaspoon baking powder',
#  '1 teaspoon baking soda',
#  '1/4 cup vegetable oil']

# %%
match_ingredient(ingreds[2])
# Out:
# 73
# Unnamed: 0                                                  115
# text                                                white sugar
# class         [{'id': 'AG.01.l.02', 'name': 'Sweetener (syru...
# Name: 2061, dtype: object

# %%
match_ingredient('active dry yeast')
# Out:
# 60
# Unnamed: 0                                                11628
# text                                             chicken breast
# class         [{'id': 'AG.01.d.02', 'name': 'Part/joint of a...
# Name: 325, dtype: object
